# %%
import json

# %% [markdown]
# # Load topics

# %%
with open('topics.json','r') as f:
    topics = json.load(f)
try:
    with open('rels.json','r') as f:
        rels = json.load(f)
except:
    rels = {}
try:
    with open('rels_inverse.json','r') as f:
        inv = json.load(f)
except:
    inv = {}

# %% [markdown]
# ## Printing the most related repos

# %%
def show_repos(repos):
    print()
    for i in range(len(repos)):
        item = repos[i]
        l = item['link']
        s = item['stargazers']
        print("{:<6} {:<10} {:<100}".format(i+1,s,l))
        print()
    return

# %% [markdown]
# # Showing inverse keys

# %%
def show_inv(inv_list):
    for i in range(len(inv_list)):
        print("\t\t"+str(i)+':\t'+inv_list[i])
    return

# %% [markdown]
# # Sort dict

# %%
def sort_dict(dictionary):
    new = {}.copy()
    keys = sorted(list(dictionary.keys()))
    for k in keys:
        new[k] = dictionary[k].copy()
    return new

# %% [markdown]
# # Get info and label

# %%
l_topics = sorted(list(topics.keys()))
l_rel = sorted(list(rels.keys()))
l_inv = sorted(list(inv.keys()))
relations = ['is-a','used-in','used-for','works-with']
n = len(l_topics)
labeled = 0

while labeled != n:
    t = l_topics[0]
    if t in l_rel:
        print('@@'*20+' '+t+' done',end='\n\n')
        l_topics.pop(0)
        labeled +=1
        print('###'*20+' '+str(labeled)+' labeled out of '+str(n),end='\n\n')
        continue
    
    
    try:
        with open('rels_inverse.json','r') as f:
            inv = json.load(f)
    except:
        inv = {}
    l_inv = sorted(list(inv.keys()))
    print(('@@'*50+'\n')*3)
    print('\n\t'+'##'*20+' '+t+' Info\n')
    with open('./topics/'+t+'/index.md','r') as f:
        content = f.read()
        print(content)
    print('\n'+'***'*5+' TOP 20 REPOS WITH THE TAG')
    show_repos(topics[t]['top_20'])
    print('\n'+'$$'*5+' KEYS INTRODUCED SO FAR')
    show_inv(l_inv)
    
    print('\n\tChoose lables for topic !!! '+t+' !!!:')
    
    labels = {}.copy()
    for r in relations:
        labels[r] = [].copy()
        inp = input('\n\t\tlables for Relation !! '+r+' !!:\t').split(',')
        for l in inp:
            k = l.strip()
            try:
                x = l_inv[int(k)]
                if x not in labels[r]:
                    labels[r].append(x)
                    inv[x][r].append(t)
                continue
            except:
                pass
            try:
                digit = int(k)
                continue
            except:
                pass
            if k != '' and k not in labels[r]:
                try:
                    inv[k][r].append(t)
                    labels[r].append(k)
                    continue
                except:
                    pass
                inv[k] = {}.copy()
                for i in relations:
                    inv[k][i] = [].copy()
                inv[k][r].append(t)
                labels[r].append(k)
    
    print('\n\t\tThe labels you have chosen for !!! '+t+' !!! are:')
    for k,v in labels.items():
        print('\t\t\t'+k+': '+str(v))
    move_on = input('\n\t\tEnter any text to redo or press enter to move to the next topic:\n\t\t\t')
    if move_on == '':
        rels[t] = labels.copy()
        rels = sort_dict(rels)
        with open('rels.json','w') as f:
            json.dump(rels,f)
        inv = sort_dict(inv)
        with open('rels_inverse.json','w') as f:
            json.dump(inv,f)
        l_topics.pop(0)
        labeled +=1
        print('\n\t'+'###'*20+' '+t+' DONE!\n')
        print('###'*20+' '+str(labeled)+' labeled out of '+str(n),end='\n\n')
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ 3d done
#
# ############################################################ 1 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ actions done
#
# ############################################################ 2 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ activitypub done
#
# ############################################################ 3 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ada done
#
# ############################################################ 4 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ai done
#
# ############################################################ 5 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ajax done
#
# ############################################################ 6 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ algolia done
#
# ############################################################ 7 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ algorithm done
#
# ############################################################ 8 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ amphp done
#
# ############################################################ 9 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ android done
#
# ############################################################ 10 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ angular done
#
# ############################################################ 11 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ anidb done
#
# ############################################################ 12 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ animal-crossing done
#
# ############################################################ 13 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ anki done
#
# ############################################################ 14 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ ansible done
#
# ############################################################ 15 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ antlr done
#
# ############################################################ 16 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ api done
#
# ############################################################ 17 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ apm done
#
# ############################################################ 18 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ archlinux done
#
# ############################################################ 19 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ arduino done
#
# ############################################################ 20 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ aspnet done
#
# ############################################################ 21 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ assemblyscript done
#
# ############################################################ 22 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ atom done
#
# ############################################################ 23 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ aurelia done
#
# ############################################################ 24 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ auth0 done
#
# ############################################################ 25 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ avalonia done
#
# ############################################################ 26 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ awesome done
#
# ############################################################ 27 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ awesomewm done
#
# ############################################################ 28 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ aws done
#
# ############################################################ 29 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ azure done
#
# ############################################################ 30 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ babel done
#
# ############################################################ 31 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ backbonejs done
#
# ############################################################ 32 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bash done
#
# ############################################################ 33 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ basic8 done
#
# ############################################################ 34 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bioinformatics done
#
# ############################################################ 35 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ biological-expression-language done
#
# ############################################################ 36 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bitcoin done
#
# ############################################################ 37 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bitcoin-cash done
#
# ############################################################ 38 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ blockchain done
#
# ############################################################ 39 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bootstrap done
#
# ############################################################ 40 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ bosque done
#
# ############################################################ 41 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## bot Info
#
# ---
# aliases: bots
# display_name: Bot
# short_description: A bot is an application that runs automated tasks over the Internet.
# topic: bot
# wikipedia_url: https://en.wikipedia.org/wiki/Internet_bot
# ---
# A bot is an application that runs automated, usually repetitive tasks over the Internet.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      15606      https://github.com/hubotio/hubot
#
# 2      14294      https://github.com/ccxt/ccxt
#
# 3      11272      https://github.com/python-telegram-bot/python-telegram-bot
#
# 4      11066      https://github.com/timgrossmann/InstaPy
#
# 5      10180      https://github.com/gunthercox/ChatterBot
#
# 6      10000      https://github.com/howdyai/botkit
#
# 7      9413       https://github.com/RasaHQ/rasa
#
# 8      8801       https://github.com/botpress/botpress
#
# 9      7545       https://github.com/sfyc23/EverydayWechat
#
# 10     6945       https://github.com/leon-ai/leon
#
# 11     6812       https://github.com/LupusLeaks/EasyFN
#
# 12     6465       https://github.com/discordjs/discord.js
#
# 13     6160       https://github.com/microsoft/botframework-sdk
#
# 14     6014       https://github.com/microsoft/ailab
#
# 15     5512       https://github.com/maxbbraun/trump2cash
#
# 16     5143       https://github.com/botman/botman
#
# 17     4495       https://github.com/deepmipt/DeepPavlov
#
# 18     4469       https://github.com/yagop/node-telegram-bot-api
#
# 19     3787       https://github.com/axa-group/nlp.js
#
# 20     3632       https://github.com/PokemonGoF/PokemonGo-Bot
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	desktop
# 		20:	dotnet
# 		21:	education
# 		22:	entertainment
# 		23:	field
# 		24:	forum
# 		25:	framework
# 		26:	frontend
# 		27:	game
# 		28:	hardware
# 		29:	html
# 		30:	javascript
# 		31:	library
# 		32:	manage
# 		33:	mobile
# 		34:	monitor
# 		35:	not-important
# 		36:	operating-system
# 		37:	organization
# 		38:	parser
# 		39:	php
# 		40:	platform
# 		41:	process
# 		42:	programming-language
# 		43:	protocol
# 		44:	representation-language
# 		45:	research
# 		46:	scientific
# 		47:	search
# 		48:	security
# 		49:	social-network
# 		50:	software-development
# 		51:	technique
# 		52:	text-editor
# 		53:	tool
# 		54:	typescript
# 		55:	ui-ux
# 		56:	under-revision
# 		57:	virtual-reality
# 		58:	visuals
# 		59:	webapp
# 		60:	x-window
#
# 	Choose lables for topic !!! bot !!!:
# 		lables for Relation !! is-a !!:	 application
#
# 		lables for Relation !! used-in !!:	 internet
#
# 		lables for Relation !! used-for !!:	 automation
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! bot !!! are:
# 			is-a: ['application']
# 			used-in: ['internet']
# 			used-for: ['automation']
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ bot DONE!
#
# ############################################################ 42 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## c Info
#
# ---
# aliases: c-language, c-programming-language
# created_by: Dennis Ritchie
# display_name: C
# logo: c.png
# related: language
# released: '1972'
# short_description: C is a general purpose programming language that first appeared
#   in 1972.
# topic: c
# url: http://www.open-std.org/jtc1/sc22/wg14/
# wikipedia_url: https://en.wikipedia.org/wiki/C_(programming_language)
# ---
# C is a programming language designed by Dennis Ritchie at Bell Labs. C is very widely used, straightforward, and can be compiled to a number of platforms and operating systems. C is an imperative language, with a small number of keywords and a large number of mathematical operators.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      37846      https://github.com/neovim/neovim
#
# 2      34971      https://github.com/Genymobile/scrcpy
#
# 3      33546      https://github.com/git/git
#
# 4      26562      https://github.com/fffaraz/awesome-cpp
#
# 5      23155      https://github.com/serhii-londar/open-source-mac-os-apps
#
# 6      21022      https://github.com/obsproject/obs-studio
#
# 7      20854      https://github.com/vim/vim
#
# 8      20667      https://github.com/ggreer/the_silver_searcher
#
# 9      20615      https://github.com/FFmpeg/FFmpeg
#
# 10     17739      https://github.com/curl/curl
#
# 11     17065      https://github.com/ruby/ruby
#
# 12     14843      https://github.com/google/flatbuffers
#
# 13     13518      https://github.com/huihut/interview
#
# 14     13224      https://github.com/vurtun/nuklear
#
# 15     13097      https://github.com/oracle/graal
#
# 16     12901      https://github.com/radareorg/radare2
#
# 17     12735      https://github.com/mpv-player/mpv
#
# 18     11866      https://github.com/allinurl/goaccess
#
# 19     11448      https://github.com/pbatard/rufus
#
# 20     11111      https://github.com/facebook/infer
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	desktop
# 		20:	dotnet
# 		21:	education
# 		22:	entertainment
# 		23:	field
# 		24:	forum
# 		25:	framework
# 		26:	frontend
# 		27:	game
# 		28:	hardware
# 		29:	html
# 		30:	internet
# 		31:	javascript
# 		32:	library
# 		33:	manage
# 		34:	mobile
# 		35:	monitor
# 		36:	not-important
# 		37:	operating-system
# 		38:	organization
# 		39:	parser
# 		40:	php
# 		41:	platform
# 		42:	process
# 		43:	programming-language
# 		44:	protocol
# 		45:	representation-language
# 		46:	research
# 		47:	scientific
# 		48:	search
# 		49:	security
# 		50:	social-network
# 		51:	software-development
# 		52:	technique
# 		53:	text-editor
# 		54:	tool
# 		55:	typescript
# 		56:	ui-ux
# 		57:	under-revision
# 		58:	virtual-reality
# 		59:	visuals
# 		60:	webapp
# 		61:	x-window
#
# 	Choose lables for topic !!! c !!!:
# 		lables for Relation !! is-a !!:	 43
#
# 		lables for Relation !! used-in !!:
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! c !!! are:
# 			is-a: ['programming-language']
# 			used-in: []
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ c DONE!
#
# ############################################################ 43 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## calculate-pi Info
#
# ---
# aliases: calculatepi, calculate-pi
# created_by: github
# display_name: Calculate Pi
# github_url: https://github.com/topics/calculate-pi
# logo: calculate-pi.png
# released: March 14, 1592
# short_description: The mathematical Constant π.
# topic: calculate-pi
# url: https://en.wikipedia.org/wiki/Pi
# wikipedia_url: https://en.wikipedia.org/wiki/Pi
# ---
#
# The number π (/paɪ/) is a mathematical constant. Originally defined as the ratio of a circle's circumference to its diameter, it now has various equivalent definitions and appears in many formulas in all areas of mathematics and physics. It is approximately equal to 3.14159. It has been represented by the Greek letter "π" since the mid-18th century, though it is also sometimes spelled out as "pi". It is also called Archimedes' constant. [Wikipedia](https://en.wikipedia.org/wiki/Pi).
#
# If you are up for the challenge, this topic contains repositories with code to solve for Pi.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      13         https://github.com/UCL-RITS/pi_examples
#
# 2      4          https://github.com/raspberrypilearning/octapi-calculating-pi
#
# 3      3          https://github.com/Nefari0uss/calculate-pi
#
# 4      3          https://github.com/yxwangcs/parallel-pi
#
# 5      3          https://github.com/sirodoht/cuda-examples
#
# 6      1          https://github.com/andreafioraldi/Grassi-PI
#
# 7      1          https://github.com/dizzarg/calculate-pi
#
# 8      1          https://github.com/ShenTengTu/ColorWithPi
#
# 9      2          https://github.com/elzup/calculate-pi-ts
#
# 10     1          https://github.com/wesbarnett/2acos0
#
# 11     1          https://github.com/Noisytoot/luapi
#
# 12     1          https://github.com/visyeii/Monte_Carlo_PI-
#
# 13     1          https://github.com/frederikpietzko/fun_with_python
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	desktop
# 		20:	dotnet
# 		21:	education
# 		22:	entertainment
# 		23:	field
# 		24:	forum
# 		25:	framework
# 		26:	frontend
# 		27:	game
# 		28:	hardware
# 		29:	html
# 		30:	internet
# 		31:	javascript
# 		32:	library
# 		33:	manage
# 		34:	mobile
# 		35:	monitor
# 		36:	not-important
# 		37:	operating-system
# 		38:	organization
# 		39:	parser
# 		40:	php
# 		41:	platform
# 		42:	process
# 		43:	programming-language
# 		44:	protocol
# 		45:	representation-language
# 		46:	research
# 		47:	scientific
# 		48:	search
# 		49:	security
# 		50:	social-network
# 		51:	software-development
# 		52:	technique
# 		53:	text-editor
# 		54:	tool
# 		55:	typescript
# 		56:	ui-ux
# 		57:	under-revision
# 		58:	virtual-reality
# 		59:	visuals
# 		60:	webapp
# 		61:	x-window
#
# 	Choose lables for topic !!! calculate-pi !!!:
# 		lables for Relation !! is-a !!:	 36
#
# 		lables for Relation !! used-in !!:
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! calculate-pi !!! are:
# 			is-a: ['not-important']
# 			used-in: []
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ calculate-pi DONE!
#
# ############################################################ 44 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## cassandra Info
#
# ---
# aliases: apache-cassandra
# created_by: Apache Software Foundation
# display_name: Apache Cassandra
# github_url: https://github.com/apache/cassandra
# logo: cassandra.png
# related: language, dotnet
# released: July 2008
# short_description: Apache Cassandra is a free, open source, distributed, NoSQL database management system.
# topic: cassandra
# url: http://cassandra.apache.org/
# wikipedia_url: https://en.wikipedia.org/wiki/Apache_Cassandra
# ---
# Apache Cassandra is a free, open source, distributed, wide column store, NoSQL database management system designed to handle large amounts of data across many commodity servers, providing high availability with no single point of failure.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      6187       https://github.com/scylladb/scylla
#
# 2      6091       https://github.com/apache/cassandra
#
# 3      4791       https://github.com/golang-migrate/migrate
#
# 4      4347       https://github.com/tschellenbach/Stream-Framework
#
# 5      4033       https://github.com/PipelineAI/pipeline
#
# 6      3478       https://github.com/JanusGraph/janusgraph
#
# 7      3303       https://github.com/rickbergfalk/sqlpad
#
# 8      2306       https://github.com/mattes/migrate
#
# 9      2057       https://github.com/PHPSocialNetwork/phpfastcache
#
# 10     1883       https://github.com/gocql/gocql
#
# 11     1721       https://github.com/datastax/spark-cassandra-connector
#
# 12     1702       https://github.com/getquill/quill
#
# 13     1437       https://github.com/strapdata/elassandra
#
# 14     1040       https://github.com/outworkers/phantom
#
# 15     1026       https://github.com/datastax/nodejs-driver
#
# 16     950        https://github.com/HariSekhon/Nagios-Plugins
#
# 17     801        https://github.com/spotify/heroic
#
# 18     743        https://github.com/HariSekhon/Dockerfiles
#
# 19     700        https://github.com/lensesio/stream-reactor
#
# 20     654        https://github.com/MachineAcuity/rebar
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	desktop
# 		20:	dotnet
# 		21:	education
# 		22:	entertainment
# 		23:	field
# 		24:	forum
# 		25:	framework
# 		26:	frontend
# 		27:	game
# 		28:	hardware
# 		29:	html
# 		30:	internet
# 		31:	javascript
# 		32:	library
# 		33:	manage
# 		34:	mobile
# 		35:	monitor
# 		36:	not-important
# 		37:	operating-system
# 		38:	organization
# 		39:	parser
# 		40:	php
# 		41:	platform
# 		42:	process
# 		43:	programming-language
# 		44:	protocol
# 		45:	representation-language
# 		46:	research
# 		47:	scientific
# 		48:	search
# 		49:	security
# 		50:	social-network
# 		51:	software-development
# 		52:	technique
# 		53:	text-editor
# 		54:	tool
# 		55:	typescript
# 		56:	ui-ux
# 		57:	under-revision
# 		58:	virtual-reality
# 		59:	visuals
# 		60:	webapp
# 		61:	x-window
#
# 	Choose lables for topic !!! cassandra !!!:
# 		lables for Relation !! is-a !!:	 dbms
#
# 		lables for Relation !! used-in !!:	 database
#
# 		lables for Relation !! used-for !!:	 nosql
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! cassandra !!! are:
# 			is-a: ['dbms']
# 			used-in: ['database']
# 			used-for: ['nosql']
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ cassandra DONE!
#
# ############################################################ 45 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## cdnjs Info
#
# ---
# created_by: Ryan Kirkman, Thomas Davis, Peter Dave, Matt Cowley
# display_name: cdnjs
# github_url: https://github.com/cdnjs/cdnjs
# url: https://cdnjs.com/
# logo: cdnjs.png
# related: cdn, javascript, css, html, library, package, opensource, foss
# topic: cdnjs
# short_description: The \#1 free and open source CDN built to make life easier for developers.
# ---
# cdnjs, the #1 CDN that is open source and free to use. Fully supporting https, SPDY, http/2 and SRI on all library assets.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      8692       https://github.com/cdnjs/cdnjs
#
# 2      3422       https://github.com/olifolkerd/tabulator
#
# 3      2395       https://github.com/0xDkd/auxpi
#
# 4      888        https://github.com/WebReflection/dom4
#
# 5      747        https://github.com/matteobruni/tsparticles
#
# 6      448        https://github.com/cdnjs/new-website
#
# 7      284        https://github.com/shirotech/webpack-cdn-plugin
#
# 8      168        https://github.com/cdnjs/tutorials
#
# 9      166        https://github.com/activewidgets/getlibs
#
# 10     109        https://github.com/frontpressorg/frontpress
#
# 11     78         https://github.com/knalli/angular-vertxbus
#
# 12     36         https://github.com/kennethreitz-archive/awesome-cdn
#
# 13     29         https://github.com/cdnjs/cdnjs-importer
#
# 14     29         https://github.com/cdnjs/atom-extension
#
# 15     20         https://github.com/int64ago/cdnjs-extension
#
# 16     17         https://github.com/joedf/strapdown-topbar
#
# 17     14         https://github.com/cdnjs/old-website
#
# 18     12         https://github.com/cdnjs/cf-stats
#
# 19     11         https://github.com/Lookyloo/sanejs
#
# 20     11         https://github.com/duuliy/vue-duuliy-multipage
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	dbms
# 		20:	desktop
# 		21:	dotnet
# 		22:	education
# 		23:	entertainment
# 		24:	field
# 		25:	forum
# 		26:	framework
# 		27:	frontend
# 		28:	game
# 		29:	hardware
# 		30:	html
# 		31:	internet
# 		32:	javascript
# 		33:	library
# 		34:	manage
# 		35:	mobile
# 		36:	monitor
# 		37:	nosql
# 		38:	not-important
# 		39:	operating-system
# 		40:	organization
# 		41:	parser
# 		42:	php
# 		43:	platform
# 		44:	process
# 		45:	programming-language
# 		46:	protocol
# 		47:	representation-language
# 		48:	research
# 		49:	scientific
# 		50:	search
# 		51:	security
# 		52:	social-network
# 		53:	software-development
# 		54:	technique
# 		55:	text-editor
# 		56:	tool
# 		57:	typescript
# 		58:	ui-ux
# 		59:	under-revision
# 		60:	virtual-reality
# 		61:	visuals
# 		62:	webapp
# 		63:	x-window
#
# 	Choose lables for topic !!! cdnjs !!!:
# 		lables for Relation !! is-a !!:	 under-revision
#
# 		lables for Relation !! used-in !!:	 webapp
#
# 		lables for Relation !! used-for !!:	 css,javascript
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! cdnjs !!! are:
# 			is-a: ['under-revision']
# 			used-in: ['webapp']
# 			used-for: ['css', 'javascript']
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 			 irik
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## cdnjs Info
#
# ---
# created_by: Ryan Kirkman, Thomas Davis, Peter Dave, Matt Cowley
# display_name: cdnjs
# github_url: https://github.com/cdnjs/cdnjs
# url: https://cdnjs.com/
# logo: cdnjs.png
# related: cdn, javascript, css, html, library, package, opensource, foss
# topic: cdnjs
# short_description: The \#1 free and open source CDN built to make life easier for developers.
# ---
# cdnjs, the #1 CDN that is open source and free to use. Fully supporting https, SPDY, http/2 and SRI on all library assets.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      8692       https://github.com/cdnjs/cdnjs
#
# 2      3422       https://github.com/olifolkerd/tabulator
#
# 3      2395       https://github.com/0xDkd/auxpi
#
# 4      888        https://github.com/WebReflection/dom4
#
# 5      747        https://github.com/matteobruni/tsparticles
#
# 6      448        https://github.com/cdnjs/new-website
#
# 7      284        https://github.com/shirotech/webpack-cdn-plugin
#
# 8      168        https://github.com/cdnjs/tutorials
#
# 9      166        https://github.com/activewidgets/getlibs
#
# 10     109        https://github.com/frontpressorg/frontpress
#
# 11     78         https://github.com/knalli/angular-vertxbus
#
# 12     36         https://github.com/kennethreitz-archive/awesome-cdn
#
# 13     29         https://github.com/cdnjs/cdnjs-importer
#
# 14     29         https://github.com/cdnjs/atom-extension
#
# 15     20         https://github.com/int64ago/cdnjs-extension
#
# 16     17         https://github.com/joedf/strapdown-topbar
#
# 17     14         https://github.com/cdnjs/old-website
#
# 18     12         https://github.com/cdnjs/cf-stats
#
# 19     11         https://github.com/Lookyloo/sanejs
#
# 20     11         https://github.com/duuliy/vue-duuliy-multipage
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	dbms
# 		20:	desktop
# 		21:	dotnet
# 		22:	education
# 		23:	entertainment
# 		24:	field
# 		25:	forum
# 		26:	framework
# 		27:	frontend
# 		28:	game
# 		29:	hardware
# 		30:	html
# 		31:	internet
# 		32:	javascript
# 		33:	library
# 		34:	manage
# 		35:	mobile
# 		36:	monitor
# 		37:	nosql
# 		38:	not-important
# 		39:	operating-system
# 		40:	organization
# 		41:	parser
# 		42:	php
# 		43:	platform
# 		44:	process
# 		45:	programming-language
# 		46:	protocol
# 		47:	representation-language
# 		48:	research
# 		49:	scientific
# 		50:	search
# 		51:	security
# 		52:	social-network
# 		53:	software-development
# 		54:	technique
# 		55:	text-editor
# 		56:	tool
# 		57:	typescript
# 		58:	ui-ux
# 		59:	under-revision
# 		60:	virtual-reality
# 		61:	visuals
# 		62:	webapp
# 		63:	x-window
#
# 	Choose lables for topic !!! cdnjs !!!:
# 		lables for Relation !! is-a !!:	 under-revision
#
# 		lables for Relation !! used-in !!:	 webapp
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:	 css,javascript
# 		The labels you have chosen for !!! cdnjs !!! are:
# 			is-a: ['under-revision']
# 			used-in: ['webapp']
# 			used-for: []
# 			works-with: ['css', 'javascript']
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ cdnjs DONE!
#
# ############################################################ 46 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## chrome Info
#
# ---
# aliases: google-chrome
# related: firefox,safari,edge,opera,chromium,browser,chrome-extension
# created_by: Google
# display_name: Chrome
# github_url: https://github.com/googlechrome
# logo: chrome.png
# released: September 2, 2008
# short_description: Chrome is a web browser from the tech company Google.
# topic: chrome
# url: https://www.google.com/chrome/
# ---
#
# Chrome is the most popular web browser worldwide as of mid-2017, made by the tech company Google. It's available for most operating systems including Windows, macOS, and Linux and on multiple platforms such as the desktop, phones, and tablets.
#
# Chrome boasts a minimalistic UI and was the first browser to feature "tabs" above the address bar, a convention that was later implemented in other browsers. Other popular features include things such as Incognito mode, tab sandboxing, and a Web Store with extensions and themes.
#
# Although Chrome is not open source, the majority of the source code is available under the Chromium moniker.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      84860      https://github.com/electron/electron
#
# 2      25102      https://github.com/FiloSottile/mkcert
#
# 3      20370      https://github.com/ovity/octotree
#
# 4      18466      https://github.com/segmentio/nightmare
#
# 5      13252      https://github.com/prisma-archive/chromeless
#
# 6      12813      https://github.com/jaywcjlove/linux-command
#
# 7      11393      https://github.com/google/WebFundamentals
#
# 8      8664       https://github.com/casesandberg/react-color
#
# 9      8394       https://github.com/checkly/puppeteer-recorder
#
# 10     7999       https://github.com/uBlock-LLC/uBlock
#
# 11     7684       https://github.com/haotian-wang/google-access-helper
#
# 12     7378       https://github.com/iamadamdev/bypass-paywalls-chrome
#
# 13     6171       https://github.com/alvarcarto/url-to-pdf-api
#
# 14     5554       https://github.com/crimx/ext-saladict
#
# 15     5104       https://github.com/chromedp/chromedp
#
# 16     4674       https://github.com/yujiosaka/headless-chrome-crawler
#
# 17     4541       https://github.com/firefox-devtools/debugger
#
# 18     4191       https://github.com/MontFerret/ferret
#
# 19     4086       https://github.com/nieweidong/fetool
#
# 20     3924       https://github.com/burtonator/polar-bookshelf
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	cicd
# 		12:	cli
# 		13:	cloud-computing
# 		14:	compiler
# 		15:	cryptocurrency
# 		16:	cs-basics
# 		17:	css
# 		18:	database
# 		19:	dbms
# 		20:	desktop
# 		21:	dotnet
# 		22:	education
# 		23:	entertainment
# 		24:	field
# 		25:	forum
# 		26:	framework
# 		27:	frontend
# 		28:	game
# 		29:	hardware
# 		30:	html
# 		31:	internet
# 		32:	javascript
# 		33:	library
# 		34:	manage
# 		35:	mobile
# 		36:	monitor
# 		37:	nosql
# 		38:	not-important
# 		39:	operating-system
# 		40:	organization
# 		41:	parser
# 		42:	php
# 		43:	platform
# 		44:	process
# 		45:	programming-language
# 		46:	protocol
# 		47:	representation-language
# 		48:	research
# 		49:	scientific
# 		50:	search
# 		51:	security
# 		52:	social-network
# 		53:	software-development
# 		54:	technique
# 		55:	text-editor
# 		56:	tool
# 		57:	typescript
# 		58:	ui-ux
# 		59:	under-revision
# 		60:	virtual-reality
# 		61:	visuals
# 		62:	webapp
# 		63:	x-window
#
# 	Choose lables for topic !!! chrome !!!:
# 		lables for Relation !! is-a !!:	 3,browser
#
# 		lables for Relation !! used-in !!:	 31
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! chrome !!! are:
# 			is-a: ['application', 'browser']
# 			used-in: ['internet']
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ chrome DONE!
#
# ############################################################ 47 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## chrome-extension Info
#
# ---
# aliases: chrome-extensions
# created_by: Google Inc.
# display_name: Chrome extension
# logo: chrome-extension.png
# released: December 8, 2009
# short_description: Google Chrome Extensions are add-ons that allow users to customize
#   their Chrome web browser.
# topic: chrome-extension
# url: https://chrome.google.com/webstore/category/extensions
# wikipedia_url: https://en.wikipedia.org/wiki/Google_Chrome_extension
# ---
# Google Chrome Extensions are add-ons that allow users to customize their Chrome web browser. They are downloadable through the Chrome Web Store. Extensions are most often written in HTML, JavaScript, and CSS.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      12266      https://github.com/sindresorhus/refined-github
#
# 2      10052      https://github.com/unbug/codelf
#
# 3      8394       https://github.com/checkly/puppeteer-recorder
#
# 4      7378       https://github.com/iamadamdev/bypass-paywalls-chrome
#
# 5      7363       https://github.com/darkreader/darkreader
#
# 6      6861       https://github.com/appbaseio/dejavu
#
# 7      6457       https://github.com/listen1/listen1_chrome_extension
#
# 8      3834       https://github.com/Kenshin/simpread
#
# 9      3574       https://github.com/dejan/rails_panel
#
# 10     3312       https://github.com/KartikTalwar/gmail.js
#
# 11     2992       https://github.com/zxlie/FeHelper
#
# 12     2939       https://github.com/lmk123/crx-selection-translate
#
# 13     2857       https://github.com/openstyles/stylus
#
# 14     2629       https://github.com/vinta/pangu.js
#
# 15     2622       https://github.com/sunoj/jjb
#
# 16     2581       https://github.com/dessant/buster
#
# 17     2560       https://github.com/WorldBrain/Memex
#
# 18     2544       https://github.com/EmailThis/extension-boilerplate
#
# 19     2513       https://github.com/RetireJS/retire.js
#
# 20     2406       https://github.com/imolorhe/altair
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	ai
# 		2:	api
# 		3:	application
# 		4:	artifact
# 		5:	as-a-service
# 		6:	asynchronous
# 		7:	authentication
# 		8:	automation
# 		9:	bioinformatics
# 		10:	blockchain
# 		11:	browser
# 		12:	cicd
# 		13:	cli
# 		14:	cloud-computing
# 		15:	compiler
# 		16:	cryptocurrency
# 		17:	cs-basics
# 		18:	css
# 		19:	database
# 		20:	dbms
# 		21:	desktop
# 		22:	dotnet
# 		23:	education
# 		24:	entertainment
# 		25:	field
# 		26:	forum
# 		27:	framework
# 		28:	frontend
# 		29:	game
# 		30:	hardware
# 		31:	html
# 		32:	internet
# 		33:	javascript
# 		34:	library
# 		35:	manage
# 		36:	mobile
# 		37:	monitor
# 		38:	nosql
# 		39:	not-important
# 		40:	operating-system
# 		41:	organization
# 		42:	parser
# 		43:	php
# 		44:	platform
# 		45:	process
# 		46:	programming-language
# 		47:	protocol
# 		48:	representation-language
# 		49:	research
# 		50:	scientific
# 		51:	search
# 		52:	security
# 		53:	social-network
# 		54:	software-development
# 		55:	technique
# 		56:	text-editor
# 		57:	tool
# 		58:	typescript
# 		59:	ui-ux
# 		60:	under-revision
# 		61:	virtual-reality
# 		62:	visuals
# 		63:	webapp
# 		64:	x-window
#
# 	Choose lables for topic !!! chrome-extension !!!:
# 		lables for Relation !! is-a !!:	 addon
#
# 		lables for Relation !! used-in !!:	 chrome
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! chrome-extension !!! are:
# 			is-a: ['addon']
# 			used-in: ['chrome']
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ chrome-extension DONE!
#
# ############################################################ 48 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## clash Info
#
# ---
# created_by: Dreamacro
# display_name: Clash
# github_url: https://github.com/Dreamacro/clash
# logo: clash.png
# topic: clash
# short_description: A rule-based tunnel in Go.
# ---
#
# A rule-based tunnel in Go. Provide you with powerful and fast network functions. Convenient for you to witness the larger network world.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      10560      https://github.com/Dreamacro/clash
#
# 2      5376       https://github.com/ACL4SSR/ACL4SSR
#
# 3      4638       https://github.com/Hackl0us/SS-Rule-Snippet
#
# 4      2364       https://github.com/tindy2013/subconverter
#
# 5      1744       https://github.com/vernesong/OpenClash
#
# 6      914        https://github.com/SukkaW/Koolshare-Clash
#
# 7      761        https://github.com/frainzy1477/luci-app-clash
#
# 8      613        https://github.com/geekdada/surgio
#
# 9      486        https://github.com/SpongeNobody/Clashy
#
# 10     476        https://github.com/kenzok8/openwrt-packages
#
# 11     457        https://github.com/eHpo1/Rules
#
# 12     378        https://github.com/lzdnico/ClashWeb
#
# 13     359        https://github.com/XinSSS/Conf-for-Surge-Shadowrocket
#
# 14     359        https://github.com/Dr-Incognito/V2Ray-Desktop
#
# 15     337        https://github.com/martincarrera/clash-royale-api
#
# 16     324        https://github.com/paradiseduo/ClashXR
#
# 17     313        https://github.com/PaPerseller/chn-iplist
#
# 18     274        https://github.com/lzdnico/subweb
#
# 19     274        https://github.com/frainzy1477/clash
#
# 20     271        https://github.com/soffchen/NanoPi-R2S
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	addon
# 		2:	ai
# 		3:	api
# 		4:	application
# 		5:	artifact
# 		6:	as-a-service
# 		7:	asynchronous
# 		8:	authentication
# 		9:	automation
# 		10:	bioinformatics
# 		11:	blockchain
# 		12:	browser
# 		13:	chrome
# 		14:	cicd
# 		15:	cli
# 		16:	cloud-computing
# 		17:	compiler
# 		18:	cryptocurrency
# 		19:	cs-basics
# 		20:	css
# 		21:	database
# 		22:	dbms
# 		23:	desktop
# 		24:	dotnet
# 		25:	education
# 		26:	entertainment
# 		27:	field
# 		28:	forum
# 		29:	framework
# 		30:	frontend
# 		31:	game
# 		32:	hardware
# 		33:	html
# 		34:	internet
# 		35:	javascript
# 		36:	library
# 		37:	manage
# 		38:	mobile
# 		39:	monitor
# 		40:	nosql
# 		41:	not-important
# 		42:	operating-system
# 		43:	organization
# 		44:	parser
# 		45:	php
# 		46:	platform
# 		47:	process
# 		48:	programming-language
# 		49:	protocol
# 		50:	representation-language
# 		51:	research
# 		52:	scientific
# 		53:	search
# 		54:	security
# 		55:	social-network
# 		56:	software-development
# 		57:	technique
# 		58:	text-editor
# 		59:	tool
# 		60:	typescript
# 		61:	ui-ux
# 		62:	under-revision
# 		63:	virtual-reality
# 		64:	visuals
# 		65:	webapp
# 		66:	x-window
#
# 	Choose lables for topic !!! clash !!!:
# 		lables for Relation !! is-a !!:	 under-revision
#
# 		lables for Relation !! used-in !!:
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! clash !!! are:
# 			is-a: ['under-revision']
# 			used-in: []
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ clash DONE!
#
# ############################################################ 49 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## cli Info
#
# ---
# aliases: commandline-interface
# created_by: Glenda Schroeder
# display_name: Command line interface
# released: '1965'
# short_description: A CLI, or command-line interface, is a console that helps users
#   issue commands to a program.
# topic: cli
# wikipedia_url: https://en.wikipedia.org/wiki/Command-line_interface
# ---
# Before there were graphical user interfaces, command-line interfaces were used to issue commands to a computer. Programs that handle the user interface are called command language interpreters, often known as a shell. A CLI may give a user more control over the computer and programs they wish to execute.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      47705      https://github.com/jakubroztocil/httpie
#
# 2      30995      https://github.com/junegunn/fzf
#
# 3      23644      https://github.com/angular/angular-cli
#
# 4      21352      https://github.com/sharkdp/bat
#
# 5      20991      https://github.com/wagoodman/dive
#
# 6      20958      https://github.com/BurntSushi/ripgrep
#
# 7      19795      https://github.com/alebcay/awesome-shell
#
# 8      19142      https://github.com/chubin/cheat.sh
#
# 9      18131      https://github.com/avajs/ava
#
# 10     17430      https://github.com/google/python-fire
#
# 11     16969      https://github.com/jesseduffield/lazygit
#
# 12     16236      https://github.com/vercel/pkg
#
# 13     15326      https://github.com/tqdm/tqdm
#
# 14     14825      https://github.com/chalk/chalk
#
# 15     14538      https://github.com/svg/svgo
#
# 16     14438      https://github.com/sharkdp/fd
#
# 17     14221      https://github.com/urfave/cli
#
# 18     13945      https://github.com/vadimdemedes/ink
#
# 19     13666      https://github.com/FormidableLabs/webpack-dashboard
#
# 20     12380      https://github.com/sherlock-project/sherlock
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	addon
# 		2:	ai
# 		3:	api
# 		4:	application
# 		5:	artifact
# 		6:	as-a-service
# 		7:	asynchronous
# 		8:	authentication
# 		9:	automation
# 		10:	bioinformatics
# 		11:	blockchain
# 		12:	browser
# 		13:	chrome
# 		14:	cicd
# 		15:	cli
# 		16:	cloud-computing
# 		17:	compiler
# 		18:	cryptocurrency
# 		19:	cs-basics
# 		20:	css
# 		21:	database
# 		22:	dbms
# 		23:	desktop
# 		24:	dotnet
# 		25:	education
# 		26:	entertainment
# 		27:	field
# 		28:	forum
# 		29:	framework
# 		30:	frontend
# 		31:	game
# 		32:	hardware
# 		33:	html
# 		34:	internet
# 		35:	javascript
# 		36:	library
# 		37:	manage
# 		38:	mobile
# 		39:	monitor
# 		40:	nosql
# 		41:	not-important
# 		42:	operating-system
# 		43:	organization
# 		44:	parser
# 		45:	php
# 		46:	platform
# 		47:	process
# 		48:	programming-language
# 		49:	protocol
# 		50:	representation-language
# 		51:	research
# 		52:	scientific
# 		53:	search
# 		54:	security
# 		55:	social-network
# 		56:	software-development
# 		57:	technique
# 		58:	text-editor
# 		59:	tool
# 		60:	typescript
# 		61:	ui-ux
# 		62:	under-revision
# 		63:	virtual-reality
# 		64:	visuals
# 		65:	webapp
# 		66:	x-window
#
# 	Choose lables for topic !!! cli !!!:
# 		lables for Relation !! is-a !!:	 tool
#
# 		lables for Relation !! used-in !!:	 56
#
# 		lables for Relation !! used-for !!:
#
# 		lables for Relation !! works-with !!:
# 		The labels you have chosen for !!! cli !!! are:
# 			is-a: ['tool']
# 			used-in: ['software-development']
# 			used-for: []
# 			works-with: []
# 		Enter any text to redo or press enter to move to the next topic:
# 	############################################################ cli DONE!
#
# ############################################################ 50 labeled out of 391
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
# 	######################################## clojure Info
#
# ---
# aliases: clj
# created_by: Rich Hickey
# display_name: Clojure
# github_url: https://github.com/clojure
# logo: clojure.png
# related: clojurescript, cljs, language
# released: October 16, 2007
# short_description: Clojure is a dynamic, general-purpose programming language.
# topic: clojure
# url: https://clojure.org/
# wikipedia_url: https://en.wikipedia.org/wiki/Clojure
# ---
# Clojure is a functional, dynamic, general-purpose programming language. It provides built-in concurrency support via software transactional memory and asynchronous agents, and offers a rich set of immutable, persistent data structures. Clojure runs on JVM, JavaScript VMs, and Common Language Runtime.
#
#
# *************** TOP 20 REPOS WITH THE TAG
#
# 1      21668      https://github.com/metabase/metabase
#
# 2      11738      https://github.com/eclipse/deeplearning4j
#
# 3      11191      https://github.com/LightTable/LightTable
#
# 4      7388       https://github.com/lk-geimfari/awesomo
#
# 5      7075       https://github.com/kanaka/mal
#
# 6      3942       https://github.com/riemann/riemann
#
# 7      3914       https://github.com/reagent-project/reagent
#
# 8      3792       https://github.com/weavejester/compojure
#
# 9      3738       https://github.com/tonsky/datascript
#
# 10     3499       https://github.com/bbatsov/clojure-style-guide
#
# 11     3354       https://github.com/izhangzhihao/intellij-rainbow-brackets
#
# 12     3151       https://github.com/ring-clojure/ring
#
# 13     2962       https://github.com/clojure-emacs/cider
#
# 14     2949       https://github.com/status-im/status-react
#
# 15     2812       https://github.com/bhauman/lein-figwheel
#
# 16     2477       https://github.com/tallesl/Rich-Hickey-fanclub
#
# 17     2433       https://github.com/twosigma/beakerx
#
# 18     2114       https://github.com/weavejester/hiccup
#
# 19     2095       https://github.com/viebel/klipse
#
# 20     2085       https://github.com/http-kit/http-kit
#
#
# $$$$$$$$$$ KEYS INTRODUCED SO FAR
# 		0:	3d-printing
# 		1:	addon
# 		2:	ai
# 		3:	api
# 		4:	application
# 		5:	artifact
# 		6:	as-a-service
# 		7:	asynchronous
# 		8:	authentication
# 		9:	automation
# 		10:	bioinformatics
# 		11:	blockchain
# 		12:	browser
# 		13:	chrome
# 		14:	cicd
# 		15:	cli
# 		16:	cloud-computing
# 		17:	compiler
# 		18:	cryptocurrency
# 		19:	cs-basics
# 		20:	css
# 		21:	database
# 		22:	dbms
# 		23:	desktop
# 		24:	dotnet
# 		25:	education
# 		26:	entertainment
# 		27:	field
# 		28:	forum
# 		29:	framework
# 		30:	frontend
# 		31:	game
# 		32:	hardware
# 		33:	html
# 		34:	internet
# 		35:	javascript
# 		36:	library
# 		37:	manage
# 		38:	mobile
# 		39:	monitor
# 		40:	nosql
# 		41:	not-important
# 		42:	operating-system
# 		43:	organization
# 		44:	parser
# 		45:	php
# 		46:	platform
# 		47:	process
# 		48:	programming-language
# 		49:	protocol
# 		50:	representation-language
# 		51:	research
# 		52:	scientific
# 		53:	search
# 		54:	security
# 		55:	social-network
# 		56:	software-development
# 		57:	technique
# 		58:	text-editor
# 		59:	tool
# 		60:	typescript
# 		61:	ui-ux
# 		62:	under-revision
# 		63:	virtual-reality
# 		64:	visuals
# 		65:	webapp
# 		66:	x-window
#
# 	Choose lables for topic !!! clojure !!!:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-90e7d1ab1b35> in <module>
#      37     for r in relations:
#      38         labels[r] = [].copy()
# ---> 39         inp = input('\n\t\tlables for Relation !! '+r+' !!:\t').split(',')
#      40         for l in inp:
#      41             k = l.strip()
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# 		lables for Relation !! is-a !!:
