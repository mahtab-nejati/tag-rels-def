# %% [markdown]
# # NOTICE : This notebook can only be used for viewing the info on each topic. For applying your modifications, you need to use the '3_2_revise.ipynb' notebook.

# %%
import json
import pandas as pd

pd.set_option('display.max_rows', 1500)

# %% [markdown]
# # Load defined relations + main topics and top 20 repos of each topic

# %%
rels = pd.read_csv('all_rels.csv')

with open('topics.json','r') as f:
    topics = json.load(f)

# %% [markdown]
# # GitHub defined tags

# %%
tags = set(topics.keys())
x = len(tags)
x
# Out:
# 391

# %% [markdown]
# # Right-Hand-Sides

# %%
rhs = set(rels['rhs'].unique())
a = len(rhs)
a
# Out:
# 167

# %% [markdown]
# # Left-Hand-Sides

# %%
lhs = set(rels['lhs'].unique())
b = len(lhs)
b
# Out:
# 391

# %% [markdown]
# # new contains topics I have added for rhs
# # old contains topics defined by GitHub that I have used for rhs

# %%
new = rhs.difference(lhs)
old = rhs.difference(new)
n = len(new)
m = len(old)
n
# Out:
# 95

# %% [markdown]
# # Get a sense of rhss

# %%
df = pd.DataFrame({'key':list(rhs),'count':0*a,'is-a':0*a,'used-in':0*a,'used-for':0*a,'works-with':0*a})

for key in rhs:
    df.loc[df['key']==key,'count'] = rels.loc[rels['rhs']==key].count()['rhs']
    df.loc[df['key']==key,'is-a'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='is-a'].count()['rhs']
    df.loc[df['key']==key,'used-in'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='used-in'].count()['rhs']
    df.loc[df['key']==key,'used-for'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='used-for'].count()['rhs']
    df.loc[df['key']==key,'works-with'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='works-with'].count()['rhs']
    
    lhss = list(rels.loc[rels.rhs==key,'lhs'])
    
    df.loc[df['key']==key,'twist-is-a'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='is-a']['rhs'].unique()))
    df.loc[df['key']==key,'twist-used-in'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='used-in']['rhs'].unique()))
    df.loc[df['key']==key,'twist-used-for'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='used-for']['rhs'].unique()))
    df.loc[df['key']==key,'twist-works-with'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='works-with']['rhs'].unique()))

df = df.sort_values('count',ascending=False).reset_index(drop='True')
rhs = list(df['key'])
display(df)
# Out:
#                               key  count  is-a  used-in  used-for  works-with  \
# 0                          webapp     55     0       55         0           0
# 1            programming-language     49    49        0         0           0
# 2                       framework     48    48        0         0           0
# 3                  under-revision     41    24       16         1           0
# 4                            tool     38    38        0         0           0
# 5                          mobile     37     0       37         0           0
# 6                      javascript     32     0        0         0          32
# 7                            game     31     9       21         1           0
# 8    software-development-process     28     0       28         0           0
# 9            software-development     27     0       27         0           0
# 10                       frontend     21     0        1        20           0
# 11                        desktop     20     0       20         0           0
# 12                          ui-ux     20     0        0        20           0
# 13                    application     19    19        0         0           0
# 14                     scientific     18     0       18         0           0
# 15                        library     15    15        0         0           0
# 16                     automation     15     0        0        15           0
# 17                        backend     14     0        0        14           0
# 18                          field     13    13        0         0           0
# 19                       platform     13    13        0         0           0
# 20                      education     12     0       11         1           0
# 21                            php     11     0        0         0          11
# 22                       database     11     1       10         0           0
# 23                             ai     10     0       10         0           0
# 24                        process     10    10        0         0           0
# 25                  entertainment     10     0       10         0           0
# 26                         manage     10     0        0        10           0
# 27               operating-system      9     9        0         0           0
# 28                       protocol      9     9        0         0           0
# 29                            web      9     0        9         0           0
# 30                            cms      8     8        0         0           0
# 31                   organization      8     8        0         0           0
# 32                          macos      8     0        0         4           4
# 33                           dbms      7     7        0         0           0
# 34                    game-engine      7     7        0         0           0
# 35                       graphics      7     3        1         3           0
# 36                cloud-computing      7     0        7         0           0
# 37                         dotnet      7     0        0         0           7
# 38                     blockchain      7     0        7         0           0
# 39                        network      7     1        6         0           0
# 40                         python      7     0        0         0           7
# 41                    text-editor      7     7        0         0           0
# 42                             2d      6     0        0         6           0
# 43                    file-format      6     6        0         0           0
# 44                package-manager      6     6        0         0           0
# 45                           java      6     0        0         0           6
# 46                          linux      6     0        0         4           2
# 47                            api      5     5        0         0           0
# 48                        browser      5     2        3         0           0
# 49                fantasy-console      5     5        0         0           0
# 50                        android      5     0        0         5           0
# 51                          html5      5     0        0         5           0
# 52                          addon      5     4        0         1           0
# 53                        windows      5     0        0         5           0
# 54                        service      5     5        0         0           0
# 55                             3d      4     0        0         4           0
# 56                        testing      4     0        0         4           0
# 57                         server      4     4        0         0           0
# 58                       security      4     0        2         2           0
# 59                       compiler      4     4        0         0           0
# 60                  communication      4     0        0         4           0
# 61                            ios      4     0        0         4           0
# 62                    competition      4     3        1         0           0
# 63                      catalogue      4     4        0         0           0
# 64                            cli      4     3        0         0           1
# 65                            ide      3     3        0         0           0
# 66                           cicd      3     0        0         3           0
# 67                markup-language      3     3        0         0           0
# 68                         search      3     0        0         3           0
# 69                site-generation      3     0        0         3           0
# 70           style-sheet-language      3     3        0         0           0
# 71                 cryptocurrency      3     3        0         0           0
# 72                       game-jam      3     3        0         0           0
# 73                  visualization      3     0        1         2           0
# 74                            cpp      3     0        0         0           3
# 75                              c      3     0        0         0           3
# 76                           chat      3     0        3         0           0
# 77                          nosql      3     0        0         3           0
# 78                     typescript      3     0        0         0           3
# 79                            iot      3     0        3         0           0
# 80                       hardware      3     1        2         0           0
# 81                  not-important      3     3        0         0           0
# 82            runtime-environment      3     3        0         0           0
# 83                 social-network      3     1        2         0           0
# 84                     relational      3     0        0         3           0
# 85                     monitoring      3     0        0         3           0
# 86                        control      2     0        0         2           0
# 87                          event      2     2        0         0           0
# 88                        grading      2     0        0         2           0
# 89                  search-engine      2     2        0         0           0
# 90                 word-processor      2     2        0         0           0
# 91                            css      2     0        0         0           2
# 92                         method      2     2        0         0           0
# 93                          forum      2     2        0         0           0
# 94                            vcs      2     2        0         0           0
# 95                 virtualization      2     0        1         1           0
# 96                           html      2     0        0         0           2
# 97                         github      2     0        0         0           2
# 98                   event-driven      2     0        0         2           0
# 99                   as-a-service      2     0        0         2           0
# 100                query-language      2     2        0         0           0
# 101                authentication      2     0        0         2           0
# 102                 collaboration      2     0        0         2           0
# 103                bioinformatics      2     0        2         0           0
# 104                          ruby      2     0        0         0           2
# 105               computer-vision      2     0        2         0           0
# 106                       license      2     2        0         0           0
# 107                      artifact      2     2        0         0           0
# 108                        nodejs      2     0        0         0           2
# 109                     cs-basics      2     2        0         0           0
# 110                  architecture      2     2        0         0           0
# 111                  microservice      2     0        0         2           0
# 112                     minecraft      2     0        0         0           2
# 113                     container      2     0        0         2           0
# 114                      practice      2     2        0         0           0
# 115                       parsing      1     0        0         1           0
# 116                      modeling      1     0        0         1           0
# 117                        elixir      1     0        0         0           1
# 118                        netbox      1     0        1         0           0
# 119                        portal      1     0        0         1           0
# 120                        cypher      1     0        0         0           1
# 121                        aspnet      1     0        0         0           1
# 122              machine-learning      1     0        1         0           0
# 123                           sdk      1     1        0         0           0
# 124                       firefox      1     0        1         0           0
# 125                          siri      1     0        0         0           1
# 126                   code-review      1     0        0         1           0
# 127                     hackathon      1     1        0         0           0
# 128                           cdn      1     1        0         0           0
# 129              image-processing      1     0        0         1           0
# 130                      firmware      1     1        0         0           0
# 131                        device      1     1        0         0           0
# 132                          code      1     0        0         1           0
# 133                  data-science      1     0        1         0           0
# 134                       dynamic      1     0        0         1           0
# 135                        chrome      1     0        1         0           0
# 136                        matlab      1     0        0         0           1
# 137             telecommunication      1     0        1         0           0
# 138                 deep-learning      1     0        1         0           0
# 139                   3d-printing      1     0        0         1           0
# 140                 state-manager      1     1        0         0           0
# 141                        metric      1     1        0         0           0
# 142                           art      1     0        1         0           0
# 143                           sql      1     0        0         0           1
# 144                        linter      1     1        0         0           0
# 145                    publishing      1     0        0         1           0
# 146                      embedded      1     0        1         0           0
# 147       representation-language      1     1        0         0           0
# 148                      ethereum      1     0        0         0           1
# 149         system-administration      1     0        1         0           0
# 150                           git      1     0        0         0           1
# 151                  code-quality      1     0        0         1           0
# 152                        octave      1     0        0         0           1
# 153                       ansible      1     0        0         0           1
# 154                           lua      1     0        0         0           1
# 155                      x-window      1     0        0         0           1
# 156                       privacy      1     0        0         1           0
# 157                       mongodb      1     0        0         0           1
# 158                     streaming      1     0        0         1           0
# 159                            go      1     0        0         0           1
# 160                       haskell      1     0        0         0           1
# 161                     community      1     1        0         0           0
# 162                  online-judge      1     1        0         0           0
# 163               virtual-reality      1     0        0         1           0
# 164                       clojure      1     0        0         0           1
# 165                   graph-based      1     0        0         1           0
# 166                     wordpress      1     0        0         0           1
#
#                                             twist-is-a  \
# 0    tool,api,framework,platform,service,library,cm...
# 1                             programming-language,ide
# 2                                   framework,platform
# 3    framework,under-revision,cdn,tool,hardware,lib...
# 4                                     tool,application
# 5    tool,api,operating-system,platform,framework,s...
# 6    tool,framework,compiler,library,runtime-enviro...
# 7    field,application,game,fantasy-console,tool,ga...
# 8    tool,process,organization,metric,framework,pra...
# 9    tool,compiler,text-editor,package-manager,runt...
# 10   framework,platform,library,style-sheet-languag...
# 11   framework,platform,state-manager,sdk,library,r...
# 12        framework,state-manager,tool,sdk,library,ide
# 13   application,game,tool,browser,word-processor,s...
# 14   field,representation-language,tool,method,fram...
# 15                                         library,api
# 16                 tool,application,practice,framework
# 17                                           framework
# 18                                               field
# 19                 operating-system,platform,framework
# 20   cs-basics,application,artifact,organization,to...
# 21               framework,package-manager,cms,library
# 22                   dbms,query-language,tool,database
# 23                             field,framework,library
# 24                                             process
# 25                    catalogue,forum,application,game
# 26                     tool,process,application,method
# 27                           operating-system,platform
# 28                                            protocol
# 29   application,browser,search-engine,protocol,server
# 30                                                 cms
# 31                                        organization
# 32            cli,game-engine,package-manager,tool,ide
# 33                                                dbms
# 34                                         game-engine
# 35                     field,graphics,tool,api,library
# 36               service,platform,library,organization
# 37                  framework,package-manager,platform
# 38      cryptocurrency,under-revision,service,platform
# 39   under-revision,protocol,organization,tool,arch...
# 40                   framework,library,package-manager
# 41                                         text-editor
# 42                                     game-engine,api
# 43                                         file-format
# 44                                     package-manager
# 45                              tool,library,framework
# 46                                     cli,game-engine
# 47                                         api,library
# 48              application,browser,addon,api,protocol
# 49                                     fantasy-console
# 50                               catalogue,game-engine
# 51                             game-engine,competition
# 52                                      addon,protocol
# 53                               game-engine,catalogue
# 54                                             service
# 55                                     game-engine,api
# 56                                      framework,tool
# 57                                              server
# 58                     service,protocol,under-revision
# 59                                            compiler
# 60                                    protocol,library
# 61                                         game-engine
# 62                            organization,competition
# 63                                     catalogue,forum
# 64                                            cli,tool
# 65                            ide,programming-language
# 66                                                tool
# 67                                     markup-language
# 68                                   api,search-engine
# 69                                      framework,tool
# 70                                style-sheet-language
# 71                                      cryptocurrency
# 72                                            game-jam
# 73               application,tool,field,under-revision
# 74                             package-manager,library
# 75                             package-manager,library
# 76                                         application
# 77                                                dbms
# 78            compiler,runtime-environment,game-engine
# 79                                protocol,tool,server
# 80                           organization,api,hardware
# 81                                       not-important
# 82                                 runtime-environment
# 83                 protocol,application,social-network
# 84                                                dbms
# 85                                        tool,process
# 86                                         tool,server
# 87                                               event
# 88                                   online-judge,tool
# 89                                       search-engine
# 90                          application,word-processor
# 91                                           framework
# 92                                              method
# 93                                     catalogue,forum
# 94                                                 vcs
# 95                                       tool,protocol
# 96                           framework,markup-language
# 97                                       api,framework
# 98                                   framework,library
# 99                                             service
# 100                                     query-language
# 101                                   service,protocol
# 102                                               tool
# 103                            representation-language
# 104                                          framework
# 105                                      field,library
# 106                                            license
# 107                                           artifact
# 108                          package-manager,framework
# 109                                          cs-basics
# 110                                       architecture
# 111                                          framework
# 112                                        tool,server
# 113                                           platform
# 114                                           practice
# 115                                               tool
# 116                                               tool
# 117                                               tool
# 118                                              addon
# 119                                          framework
# 120                                               dbms
# 121                                                cms
# 122                                            library
# 123                                                sdk
# 124                                              addon
# 125                                             server
# 126                                               tool
# 127                                          hackathon
# 128                                                cdn
# 129                                               tool
# 130                                           firmware
# 131                                             device
# 132                                               tool
# 133                                              field
# 134                                               tool
# 135                                              addon
# 136                                            library
# 137                                             server
# 138                                            library
# 139                                              field
# 140                                      state-manager
# 141                                             metric
# 142                                          community
# 143                                               dbms
# 144                                             linter
# 145                                          community
# 146                                            library
# 147                            representation-language
# 148                                            service
# 149                                               tool
# 150                                                vcs
# 151                                            process
# 152                                            library
# 153                                               tool
# 154                                runtime-environment
# 155                                   application,tool
# 156                                               tool
# 157                                               tool
# 158                                           platform
# 159                                          framework
# 160                                            library
# 161                                          community
# 162                                       online-judge
# 163                                              field
# 164                                           compiler
# 165                                               dbms
# 166                                                cms
#
#                                          twist-used-in  \
# 0                                mobile,webapp,desktop
# 1                                 software-development
# 2    under-revision,desktop,mobile,webapp,software-...
# 3    under-revision,network,blockchain,webapp,security
# 4    software-development-process,mobile,webapp,sof...
# 5                       mobile,webapp,desktop,embedded
# 6    mobile,webapp,desktop,software-development,fro...
# 7                          graphics,entertainment,game
# 8                software-development-process,hardware
# 9                                 software-development
# 10                      desktop,mobile,webapp,frontend
# 11                      desktop,mobile,webapp,embedded
# 12   desktop,mobile,webapp,software-development-pro...
# 13   entertainment,education,visualization,web,chat...
# 14           scientific,ai,bioinformatics,data-science
# 15   mobile,webapp,desktop,embedded,cloud-computing...
# 16   software-development-process,web,frontend,iot,...
# 17                               webapp,desktop,mobile
# 18   graphics,scientific,ai,data-science,computer-v...
# 19   mobile,desktop,webapp,cloud-computing,software...
# 20              education,software-development-process
# 21   under-revision,software-development-process,so...
# 22                                            database
# 23   ai,scientific,computer-vision,machine-learning...
# 24         software-development-process,under-revision
# 25                                       entertainment
# 26   software-development-process,visualization,und...
# 27                                              mobile
# 28   social-network,iot,web,network,virtualization,...
# 29                                                 web
# 30                                       mobile,webapp
# 31   hardware,software-development-process,educatio...
# 32             game,mobile,webapp,software-development
# 33                                            database
# 34                                                game
# 35                              graphics,mobile,webapp
# 36                                     cloud-computing
# 37                 desktop,mobile,software-development
# 38                                          blockchain
# 39                                             network
# 40   webapp,cloud-computing,computer-vision,softwar...
# 41                                software-development
# 42                                       game,hardware
# 43
# 44                                software-development
# 45   scientific,desktop,embedded,mobile,software-de...
# 46                                                game
# 47   mobile,webapp,software-development-process,har...
# 48                                         web,browser
# 49                                                game
# 50                                                game
# 51                                                game
# 52                       chrome,firefox,netbox,browser
# 53                                                game
# 54            mobile,webapp,cloud-computing,blockchain
# 55                                       game,hardware
# 56                        software-development-process
# 57                      telecommunication,iot,web,game
# 58                          mobile,webapp,web,security
# 59                                software-development
# 60                                                 web
# 61                                                game
# 62                                    competition,game
# 63                                       entertainment
# 64                                      under-revision
# 65                  software-development,mobile,webapp
# 66                        software-development-process
# 67                                              webapp
# 68                                   mobile,webapp,web
# 69                                       mobile,webapp
# 70                                              webapp
# 71                                          blockchain
# 72                                                game
# 73        visualization,data-science,scientific,webapp
# 74   software-development,computer-vision,ai,deep-l...
# 75                software-development,computer-vision
# 76                                                chat
# 77                                            database
# 78                           software-development,game
# 79                                                 iot
# 80   hardware,software-development-process,under-re...
# 81
# 82          software-development,desktop,mobile,webapp
# 83                                      social-network
# 84                                            database
# 85                        software-development-process
# 86                                      scientific,iot
# 87
# 88                                           education
# 89                                                 web
# 90
# 91                                              webapp
# 92                                          scientific
# 93                                       entertainment
# 94                        software-development-process
# 95                system-administration,virtualization
# 96                                              webapp
# 97                        software-development-process
# 98                                      under-revision
# 99                                     cloud-computing
# 100                                           database
# 101                             mobile,webapp,security
# 102                       software-development-process
# 103                          bioinformatics,scientific
# 104                                             webapp
# 105                                 ai,computer-vision
# 106                                         scientific
# 107                                          education
# 108  software-development,software-development-process
# 109                                          education
# 110                                            network
# 111                                      mobile,webapp
# 112                                               game
# 113               cloud-computing,software-development
# 114  software-development-process,software-development
# 115                               software-development
# 116                                           database
# 117                       software-development-process
# 118                                             netbox
# 119                                          education
# 120                                           database
# 121
# 122                                ai,machine-learning
# 123                              desktop,mobile,webapp
# 124                                            firefox
# 125                                                iot
# 126                       software-development-process
# 127                                               game
# 128                                     under-revision
# 129                                         scientific
# 130
# 131
# 132                                         scientific
# 133                            data-science,scientific
# 134                                      mobile,webapp
# 135                                             chrome
# 136                                    computer-vision
# 137                                  telecommunication
# 138                                   ai,deep-learning
# 139                                           graphics
# 140                              desktop,mobile,webapp
# 141                       software-development-process
# 142                                                art
# 143                                           database
# 144                               software-development
# 145                                                art
# 146                            desktop,embedded,mobile
# 147                          bioinformatics,scientific
# 148                                         blockchain
# 149                              system-administration
# 150                       software-development-process
# 151                       software-development-process
# 152                                    computer-vision
# 153                       software-development-process
# 154                               software-development
# 155                                      visualization
# 156                                                iot
# 157                                           database
# 158                                               game
# 159                                             webapp
# 160
# 161                                                art
# 162                                          education
# 163                                           graphics
# 164                               software-development
# 165                                           database
# 166
#
#                                         twist-used-for  \
# 0    dynamic,search,frontend,backend,authentication...
# 1
# 2    event-driven,frontend,backend,ui-ux,testing,si...
# 3    event-driven,manage,visualization,automation,u...
# 4    automation,cicd,dynamic,manage,monitoring,pars...
# 5    dynamic,search,frontend,authentication,securit...
# 6    dynamic,frontend,ui-ux,backend,automation,html...
# 7    3d-printing,game,virtual-reality,2d,android,ht...
# 8    automation,cicd,manage,monitoring,code-quality...
# 9                             parsing,manage,container
# 10                   frontend,backend,ui-ux,automation
# 11                              frontend,ui-ux,backend
# 12               frontend,ui-ux,collaboration,graphics
# 13                                   manage,automation
# 14         visualization,control,image-processing,code
# 15   frontend,ui-ux,communication,event-driven,grap...
# 16   automation,cicd,manage,monitoring,privacy,test...
# 17                                    backend,frontend
# 18      3d-printing,game,virtual-reality,visualization
# 19                        frontend,container,streaming
# 20                code-review,education,grading,portal
# 21          event-driven,testing,backend,communication
# 22               nosql,modeling,relational,graph-based
# 23
# 24                      manage,monitoring,code-quality
# 25
# 26                   automation,cicd,manage,monitoring
# 27
# 28         communication,security,authentication,addon
# 29            automation,search,communication,security
# 30
# 31
# 32   2d,android,html5,ios,linux,macos,windows,3d,gr...
# 33                        nosql,relational,graph-based
# 34         2d,android,html5,ios,linux,macos,windows,3d
# 35     3d-printing,game,virtual-reality,graphics,ui-ux
# 36                              as-a-service,container
# 37                                      frontend,ui-ux
# 38
# 39                                              manage
# 40                                             backend
# 41
# 42         2d,android,html5,ios,linux,macos,windows,3d
# 43
# 44
# 45      image-processing,ui-ux,automation,microservice
# 46         2d,android,html5,ios,linux,macos,windows,3d
# 47                               search,2d,3d,graphics
# 48                                               addon
# 49
# 50         android,2d,html5,ios,linux,macos,windows,3d
# 51         2d,android,html5,ios,linux,macos,windows,3d
# 52                                               addon
# 53         2d,android,html5,ios,linux,macos,windows,3d
# 54                authentication,security,as-a-service
# 55         2d,3d,android,html5,ios,linux,macos,windows
# 56                                  testing,automation
# 57                                             control
# 58               authentication,security,communication
# 59
# 60                              communication,security
# 61         2d,android,html5,ios,linux,macos,windows,3d
# 62                                               html5
# 63                                     android,windows
# 64
# 65                                               ui-ux
# 66                   automation,cicd,manage,monitoring
# 67                                            frontend
# 68                                              search
# 69                                     site-generation
# 70                                            frontend
# 71
# 72
# 73                                manage,visualization
# 74
# 75
# 76
# 77                                               nosql
# 78                                            2d,html5
# 79                          automation,privacy,control
# 80                                               2d,3d
# 81
# 82
# 83
# 84                                          relational
# 85                   automation,cicd,manage,monitoring
# 86                                             control
# 87
# 88                                             grading
# 89                                              search
# 90
# 91                                      frontend,ui-ux
# 92                                              manage
# 93
# 94
# 95                           automation,virtualization
# 96                                            frontend
# 97                                          automation
# 98                                        event-driven
# 99                                        as-a-service
# 100
# 101                            authentication,security
# 102                                collaboration,ui-ux
# 103
# 104                            site-generation,backend
# 105
# 106
# 107
# 108                                         automation
# 109
# 110
# 111                                       microservice
# 112
# 113                                          container
# 114                                         automation
# 115                                            parsing
# 116                                           modeling
# 117                              code-review,education
# 118
# 119                                             portal
# 120                                        graph-based
# 121
# 122
# 123                                              ui-ux
# 124
# 125                                            control
# 126                              code-review,education
# 127
# 128
# 129                                   image-processing
# 130
# 131
# 132                                               code
# 133                                      visualization
# 134                                            dynamic
# 135
# 136
# 137
# 138
# 139                   3d-printing,game,virtual-reality
# 140                                              ui-ux
# 141
# 142                                         publishing
# 143                                         relational
# 144
# 145                                         publishing
# 146                                              ui-ux
# 147
# 148
# 149                          automation,virtualization
# 150
# 151                                       code-quality
# 152
# 153                                            testing
# 154
# 155                                             manage
# 156                                 automation,privacy
# 157                                           modeling
# 158                                          streaming
# 159                                            backend
# 160
# 161                                         publishing
# 162                                            grading
# 163                   3d-printing,game,virtual-reality
# 164
# 165                                        graph-based
# 166
#
#                                       twist-works-with
# 0    javascript,css,html,python,go,ruby,php,macos,java
# 1
# 2    php,javascript,dotnet,css,html,python,go,ruby,...
# 3                              php,cli,java,javascript
# 4    javascript,x-window,elixir,minecraft,java,ansi...
# 5                         javascript,dotnet,java,macos
# 6    javascript,css,html,typescript,c,cpp,java,matl...
# 7                      minecraft,javascript,typescript
# 8            php,elixir,git,github,java,ansible,nodejs
# 9    typescript,javascript,clojure,php,c,cpp,lua,no...
# 10                          javascript,dotnet,css,html
# 11                              javascript,dotnet,java
# 12                    dotnet,javascript,java,macos,css
# 13                                            x-window
# 14                                                java
# 15   javascript,java,python,c,cpp,matlab,octave,php...
# 16                       javascript,java,github,nodejs
# 17                       python,javascript,go,php,ruby
# 18
# 19                                              dotnet
# 20                                              elixir
# 21                                                 php
# 22                                  mongodb,sql,cypher
# 23                                          python,cpp
# 24
# 25
# 26                                            x-window
# 27
# 28
# 29
# 30                                php,aspnet,wordpress
# 31
# 32                                         linux,macos
# 33                                          sql,cypher
# 34                               javascript,typescript
# 35                                    macos,javascript
# 36                                              python
# 37                                              dotnet
# 38                                            ethereum
# 39
# 40          python,c,cpp,java,javascript,matlab,octave
# 41
# 42                               javascript,typescript
# 43
# 44                php,c,cpp,macos,nodejs,dotnet,python
# 45          java,c,cpp,javascript,matlab,octave,python
# 46                                         linux,macos
# 47                                   github,javascript
# 48                                          javascript
# 49
# 50
# 51                               javascript,typescript
# 52
# 53
# 54                                            ethereum
# 55
# 56                                         php,ansible
# 57                                      siri,minecraft
# 58
# 59                       typescript,javascript,clojure
# 60                                                 php
# 61
# 62                                          javascript
# 63
# 64                                     linux,macos,cli
# 65                                               macos
# 66
# 67                                                html
# 68
# 69                                                ruby
# 70
# 71
# 72
# 73                                            x-window
# 74          c,cpp,java,javascript,matlab,octave,python
# 75          c,cpp,java,javascript,matlab,octave,python
# 76
# 77
# 78                               typescript,javascript
# 79                                                siri
# 80
# 81
# 82                           javascript,typescript,lua
# 83
# 84                                                 sql
# 85
# 86                                                siri
# 87
# 88
# 89
# 90
# 91                                 css,html,javascript
# 92
# 93
# 94                                                 git
# 95
# 96                                 css,html,javascript
# 97                                       github,nodejs
# 98                                                 php
# 99
# 100
# 101
# 102
# 103
# 104                                               ruby
# 105         c,cpp,java,javascript,matlab,octave,python
# 106
# 107
# 108                                      nodejs,github
# 109
# 110
# 111                                    javascript,java
# 112                                          minecraft
# 113
# 114
# 115
# 116                                            mongodb
# 117                                             elixir
# 118
# 119
# 120                                             cypher
# 121                                             aspnet
# 122                                             python
# 123
# 124
# 125                                               siri
# 126                                             elixir
# 127
# 128
# 129                                               java
# 130
# 131
# 132
# 133
# 134                                         javascript
# 135
# 136         c,cpp,java,javascript,matlab,octave,python
# 137
# 138                                         cpp,python
# 139
# 140                                         javascript
# 141
# 142
# 143                                                sql
# 144                                         javascript
# 145
# 146                                               java
# 147
# 148                                           ethereum
# 149
# 150                                                git
# 151
# 152         c,cpp,java,javascript,matlab,octave,python
# 153                                            ansible
# 154                                                lua
# 155                                           x-window
# 156
# 157                                            mongodb
# 158
# 159                                                 go
# 160                                            haskell
# 161
# 162
# 163
# 164                                            clojure
# 165                                             cypher
# 166                                          wordpress

# %% [markdown]
# # Display top 20 repos of a topic

# %%
def show_repos(repos):
    print()
    for i in range(len(repos)):
        item = repos[i]
        l = item['link']
        s = item['stargazers']
        print("{:<6} {:<10} {:<100}".format(i+1,s,l))
        print()
    return

# %% [markdown]
# # Display info on a topic

# %%
def show_tag_info(t):    
    print(('@@'*50+'\n')*3)
    print('\n\t'+'##'*20+' '+t+' Info\n')
    with open('./topics/'+t+'/index.md','r') as f:
        content = f.read()
        print(content)

# %% [markdown]
# # Review the topics
# # NOTICE : Remove the 'revision_done.json' file or modify the list of 'done' topics in the file so that the information is displayed. This file persists your progress.
# # NOTICE : As soon as you move on to the next topic by pressing Enter, the previous topic will be excluded from any future executions unless you remove it from the 'revision_done.json' file.
# # NOTICE : Type in 'e' at any time you are asked for an input to stop revising the topics. This will not persist your revision on the current topic.
# # NOTICE : Set verbose to False for a less verbose option. (not recommended)

# %%
verbose = True

try:
    with open('revision_done.json','r') as f:
        done = json.load(f)['done']
except:
    done = [].copy()

for r in rhs:
    resp = ''
    lhss = sorted(list(set(rels.loc[rels.rhs==r,'lhs']).difference(set(done))))
    
    if verbose:
        resp = input('\nNew RHS started with '+str(len(lhss))+' LHS === '+r+'\n')
        if resp == 'e':
            break
        display(df.loc[df.key == r,['key','count','is-a','used-in','used-for','works-with']])
    while True:
        try:
            l = lhss[0]
        except:
            break
        check = rels.loc[rels.lhs==l].copy()
        show_tag_info(l)
        display(check)
        resp = input('Enter if you are done with this tag or type in "m" for more information (top 20 repos with the tag):\n')
        if resp == 'm':
            show_repos(topics[l]['top_20'])
            resp = input('Enter if you are done with this tag: ')
        if resp == 'e':
            break
        done.append(lhss.pop(0))
        with open('revision_done.json','w') as f:
            json.dump({'done':done},f)
    if resp == 'e':
        break
# Out:
# New RHS started with 0 LHS === webapp
#       key  count  is-a  used-in  used-for  works-with
# 0  webapp     55     0       55         0           0
# New RHS started with 0 LHS === programming-language
#                     key  count  is-a  used-in  used-for  works-with
# 1  programming-language     49    49        0         0           0
# New RHS started with 0 LHS === framework
#  e
