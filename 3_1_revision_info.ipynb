# %% [markdown]
# # NOTICE : This notebook can only be used for viewing the info on each topic. For applying your modifications, you need to use the '3_2_revise.ipynb' notebook.

# %%
import json
import pandas as pd

pd.set_option('display.max_rows', 1500)

# %% [markdown]
# # Load defined relations + main topics and top 20 repos of each topic

# %%
rels = pd.read_csv('all_rels.csv')

with open('topics.json','r') as f:
    topics = json.load(f)

# %% [markdown]
# # GitHub defined tags

# %%
tags = set(topics.keys())
x = len(tags)
x
# Out:
# 391

# %% [markdown]
# # Right-Hand-Sides

# %%
rhs = set(rels['rhs'].unique())
a = len(rhs)
a
# Out:
# 167

# %% [markdown]
# # Left-Hand-Sides

# %%
lhs = set(rels['lhs'].unique())
b = len(lhs)
b
# Out:
# 391

# %% [markdown]
# # new contains topics I have added for rhs
# # old contains topics defined by GitHub that I have used for rhs

# %%
new = rhs.difference(lhs)
old = rhs.difference(new)
n = len(new)
m = len(old)
with open('newly_defined.json','w') as f:
    json.dump({'new':sorted(list(new))},f)

# %% [markdown]
# # Get a sense of rhss

# %%
df = pd.DataFrame({'key':list(rhs),'count':0*a,'is-a':0*a,'used-in':0*a,'used-for':0*a,'works-with':0*a})

for key in rhs:
    df.loc[df['key']==key,'count'] = rels.loc[rels['rhs']==key].count()['rhs']
    df.loc[df['key']==key,'is-a'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='is-a'].count()['rhs']
    df.loc[df['key']==key,'used-in'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='used-in'].count()['rhs']
    df.loc[df['key']==key,'used-for'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='used-for'].count()['rhs']
    df.loc[df['key']==key,'works-with'] = rels.loc[rels['rhs']==key].loc[rels['relation']=='works-with'].count()['rhs']
    
    lhss = list(rels.loc[rels.rhs==key,'lhs'])
    
    df.loc[df['key']==key,'twist-is-a'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='is-a']['rhs'].unique()))
    df.loc[df['key']==key,'twist-used-in'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='used-in']['rhs'].unique()))
    df.loc[df['key']==key,'twist-used-for'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='used-for']['rhs'].unique()))
    df.loc[df['key']==key,'twist-works-with'] = ','.join(
        list(rels.loc[rels['lhs'].isin(lhss)].loc[rels['relation']=='works-with']['rhs'].unique()))

df = df.sort_values('count',ascending=False).reset_index(drop='True')
rhs = list(df['key'])
display(df)
# Out:
#                               key  count  is-a  used-in  used-for  works-with  \
# 0                          webapp     55     0       55         0           0
# 1            programming-language     49    49        0         0           0
# 2                       framework     48    48        0         0           0
# 3                  under-revision     41    24       16         1           0
# 4                            tool     38    38        0         0           0
# 5                          mobile     37     0       37         0           0
# 6                      javascript     32     0        0         0          32
# 7                            game     31     9       21         1           0
# 8    software-development-process     28     0       28         0           0
# 9            software-development     27     0       27         0           0
# 10                       frontend     21     0        1        20           0
# 11                        desktop     20     0       20         0           0
# 12                          ui-ux     20     0        0        20           0
# 13                    application     19    19        0         0           0
# 14                     scientific     18     0       18         0           0
# 15                     automation     15     0        0        15           0
# 16                        library     15    15        0         0           0
# 17                        backend     14     0        0        14           0
# 18                       platform     13    13        0         0           0
# 19                          field     13    13        0         0           0
# 20                      education     12     0       11         1           0
# 21                            php     11     0        0         0          11
# 22                       database     11     1       10         0           0
# 23                             ai     10     0       10         0           0
# 24                         manage     10     0        0        10           0
# 25                        process     10    10        0         0           0
# 26                  entertainment     10     0       10         0           0
# 27               operating-system      9     9        0         0           0
# 28                       protocol      9     9        0         0           0
# 29                            web      9     0        9         0           0
# 30                   organization      8     8        0         0           0
# 31                          macos      8     0        0         4           4
# 32                            cms      8     8        0         0           0
# 33                cloud-computing      7     0        7         0           0
# 34                         python      7     0        0         0           7
# 35                        network      7     1        6         0           0
# 36                    text-editor      7     7        0         0           0
# 37                       graphics      7     3        1         3           0
# 38                           dbms      7     7        0         0           0
# 39                     blockchain      7     0        7         0           0
# 40                    game-engine      7     7        0         0           0
# 41                         dotnet      7     0        0         0           7
# 42                    file-format      6     6        0         0           0
# 43                          linux      6     0        0         4           2
# 44                package-manager      6     6        0         0           0
# 45                             2d      6     0        0         6           0
# 46                           java      6     0        0         0           6
# 47                          html5      5     0        0         5           0
# 48                        browser      5     2        3         0           0
# 49                fantasy-console      5     5        0         0           0
# 50                        service      5     5        0         0           0
# 51                        windows      5     0        0         5           0
# 52                            api      5     5        0         0           0
# 53                        android      5     0        0         5           0
# 54                          addon      5     4        0         1           0
# 55                  communication      4     0        0         4           0
# 56                       compiler      4     4        0         0           0
# 57                       security      4     0        2         2           0
# 58                             3d      4     0        0         4           0
# 59                    competition      4     3        1         0           0
# 60                        testing      4     0        0         4           0
# 61                      catalogue      4     4        0         0           0
# 62                         server      4     4        0         0           0
# 63                            cli      4     3        0         0           1
# 64                            ios      4     0        0         4           0
# 65                              c      3     0        0         0           3
# 66                markup-language      3     3        0         0           0
# 67                         search      3     0        0         3           0
# 68                  not-important      3     3        0         0           0
# 69                           cicd      3     0        0         3           0
# 70                           chat      3     0        3         0           0
# 71                            ide      3     3        0         0           0
# 72                            iot      3     0        3         0           0
# 73           style-sheet-language      3     3        0         0           0
# 74                     relational      3     0        0         3           0
# 75                          nosql      3     0        0         3           0
# 76                       game-jam      3     3        0         0           0
# 77                 cryptocurrency      3     3        0         0           0
# 78                            cpp      3     0        0         0           3
# 79                       hardware      3     1        2         0           0
# 80                 social-network      3     1        2         0           0
# 81                     typescript      3     0        0         0           3
# 82                     monitoring      3     0        0         3           0
# 83            runtime-environment      3     3        0         0           0
# 84                  visualization      3     0        1         2           0
# 85                site-generation      3     0        0         3           0
# 86                       practice      2     2        0         0           0
# 87                 query-language      2     2        0         0           0
# 88                         github      2     0        0         0           2
# 89                      container      2     0        0         2           0
# 90                          event      2     2        0         0           0
# 91                  search-engine      2     2        0         0           0
# 92                         nodejs      2     0        0         0           2
# 93                 word-processor      2     2        0         0           0
# 94                          forum      2     2        0         0           0
# 95                 virtualization      2     0        1         1           0
# 96                      minecraft      2     0        0         0           2
# 97                         method      2     2        0         0           0
# 98                       artifact      2     2        0         0           0
# 99                   microservice      2     0        0         2           0
# 100                       control      2     0        0         2           0
# 101                           vcs      2     2        0         0           0
# 102                          ruby      2     0        0         0           2
# 103                bioinformatics      2     0        2         0           0
# 104                          html      2     0        0         0           2
# 105                  as-a-service      2     0        0         2           0
# 106               computer-vision      2     0        2         0           0
# 107                       grading      2     0        0         2           0
# 108                 collaboration      2     0        0         2           0
# 109                       license      2     2        0         0           0
# 110                  event-driven      2     0        0         2           0
# 111                authentication      2     0        0         2           0
# 112                  architecture      2     2        0         0           0
# 113                     cs-basics      2     2        0         0           0
# 114                           css      2     0        0         0           2
# 115                     hackathon      1     1        0         0           0
# 116                            go      1     0        0         0           1
# 117                     community      1     1        0         0           0
# 118                       ansible      1     0        0         0           1
# 119                  online-judge      1     1        0         0           0
# 120              machine-learning      1     0        1         0           0
# 121                        portal      1     0        0         1           0
# 122                       parsing      1     0        0         1           0
# 123                        chrome      1     0        1         0           0
# 124               virtual-reality      1     0        0         1           0
# 125                      ethereum      1     0        0         0           1
# 126                 deep-learning      1     0        1         0           0
# 127                        matlab      1     0        0         0           1
# 128                        cypher      1     0        0         0           1
# 129                           lua      1     0        0         0           1
# 130                        octave      1     0        0         0           1
# 131                       dynamic      1     0        0         1           0
# 132                       clojure      1     0        0         0           1
# 133                   code-review      1     0        0         1           0
# 134                   graph-based      1     0        0         1           0
# 135                      x-window      1     0        0         0           1
# 136                          code      1     0        0         1           0
# 137                      firmware      1     1        0         0           0
# 138                           sdk      1     1        0         0           0
# 139                 state-manager      1     1        0         0           0
# 140                        linter      1     1        0         0           0
# 141                    publishing      1     0        0         1           0
# 142                  data-science      1     0        1         0           0
# 143                       mongodb      1     0        0         0           1
# 144             telecommunication      1     0        1         0           0
# 145                        metric      1     1        0         0           0
# 146                           sql      1     0        0         0           1
# 147                   3d-printing      1     0        0         1           0
# 148                        elixir      1     0        0         0           1
# 149                       firefox      1     0        1         0           0
# 150                        netbox      1     0        1         0           0
# 151                     wordpress      1     0        0         0           1
# 152                      embedded      1     0        1         0           0
# 153                       privacy      1     0        0         1           0
# 154                  code-quality      1     0        0         1           0
# 155                        aspnet      1     0        0         0           1
# 156                          siri      1     0        0         0           1
# 157              image-processing      1     0        0         1           0
# 158       representation-language      1     1        0         0           0
# 159                       haskell      1     0        0         0           1
# 160                      modeling      1     0        0         1           0
# 161                           git      1     0        0         0           1
# 162                           art      1     0        1         0           0
# 163                        device      1     1        0         0           0
# 164                     streaming      1     0        0         1           0
# 165                           cdn      1     1        0         0           0
# 166         system-administration      1     0        1         0           0
#
#                                             twist-is-a  \
# 0    tool,api,framework,platform,service,library,cm...
# 1                             programming-language,ide
# 2                                   framework,platform
# 3    framework,under-revision,cdn,tool,hardware,lib...
# 4                                     tool,application
# 5    tool,api,operating-system,platform,framework,s...
# 6    tool,framework,compiler,library,runtime-enviro...
# 7    field,application,game,fantasy-console,tool,ga...
# 8    tool,process,organization,metric,framework,pra...
# 9    tool,compiler,text-editor,package-manager,runt...
# 10   framework,platform,library,style-sheet-languag...
# 11   framework,platform,state-manager,sdk,library,r...
# 12        framework,state-manager,tool,sdk,library,ide
# 13   application,game,tool,browser,word-processor,s...
# 14   field,representation-language,tool,method,fram...
# 15                 tool,application,practice,framework
# 16                                         library,api
# 17                                           framework
# 18                 operating-system,platform,framework
# 19                                               field
# 20   cs-basics,application,artifact,organization,to...
# 21               framework,package-manager,cms,library
# 22                   dbms,query-language,tool,database
# 23                             field,framework,library
# 24                     tool,process,application,method
# 25                                             process
# 26                    catalogue,forum,application,game
# 27                           operating-system,platform
# 28                                            protocol
# 29   application,browser,search-engine,protocol,server
# 30                                        organization
# 31            cli,game-engine,package-manager,tool,ide
# 32                                                 cms
# 33               service,platform,library,organization
# 34                   framework,library,package-manager
# 35   under-revision,protocol,organization,tool,arch...
# 36                                         text-editor
# 37                     field,graphics,tool,api,library
# 38                                                dbms
# 39      cryptocurrency,under-revision,service,platform
# 40                                         game-engine
# 41                  framework,package-manager,platform
# 42                                         file-format
# 43                                     cli,game-engine
# 44                                     package-manager
# 45                                     game-engine,api
# 46                              tool,library,framework
# 47                             game-engine,competition
# 48              application,browser,addon,api,protocol
# 49                                     fantasy-console
# 50                                             service
# 51                               game-engine,catalogue
# 52                                         api,library
# 53                               catalogue,game-engine
# 54                                      addon,protocol
# 55                                    protocol,library
# 56                                            compiler
# 57                     service,protocol,under-revision
# 58                                     game-engine,api
# 59                            organization,competition
# 60                                      framework,tool
# 61                                     catalogue,forum
# 62                                              server
# 63                                            cli,tool
# 64                                         game-engine
# 65                             package-manager,library
# 66                                     markup-language
# 67                                   api,search-engine
# 68                                       not-important
# 69                                                tool
# 70                                         application
# 71                            ide,programming-language
# 72                                protocol,tool,server
# 73                                style-sheet-language
# 74                                                dbms
# 75                                                dbms
# 76                                            game-jam
# 77                                      cryptocurrency
# 78                             package-manager,library
# 79                           organization,api,hardware
# 80                 protocol,application,social-network
# 81            compiler,runtime-environment,game-engine
# 82                                        tool,process
# 83                                 runtime-environment
# 84               application,tool,field,under-revision
# 85                                      framework,tool
# 86                                            practice
# 87                                      query-language
# 88                                       api,framework
# 89                                            platform
# 90                                               event
# 91                                       search-engine
# 92                           package-manager,framework
# 93                          application,word-processor
# 94                                     catalogue,forum
# 95                                       tool,protocol
# 96                                         tool,server
# 97                                              method
# 98                                            artifact
# 99                                           framework
# 100                                        tool,server
# 101                                                vcs
# 102                                          framework
# 103                            representation-language
# 104                          framework,markup-language
# 105                                            service
# 106                                      field,library
# 107                                  online-judge,tool
# 108                                               tool
# 109                                            license
# 110                                  framework,library
# 111                                   service,protocol
# 112                                       architecture
# 113                                          cs-basics
# 114                                          framework
# 115                                          hackathon
# 116                                          framework
# 117                                          community
# 118                                               tool
# 119                                       online-judge
# 120                                            library
# 121                                          framework
# 122                                               tool
# 123                                              addon
# 124                                              field
# 125                                            service
# 126                                            library
# 127                                            library
# 128                                               dbms
# 129                                runtime-environment
# 130                                            library
# 131                                               tool
# 132                                           compiler
# 133                                               tool
# 134                                               dbms
# 135                                   application,tool
# 136                                               tool
# 137                                           firmware
# 138                                                sdk
# 139                                      state-manager
# 140                                             linter
# 141                                          community
# 142                                              field
# 143                                               tool
# 144                                             server
# 145                                             metric
# 146                                               dbms
# 147                                              field
# 148                                               tool
# 149                                              addon
# 150                                              addon
# 151                                                cms
# 152                                            library
# 153                                               tool
# 154                                            process
# 155                                                cms
# 156                                             server
# 157                                               tool
# 158                            representation-language
# 159                                            library
# 160                                               tool
# 161                                                vcs
# 162                                          community
# 163                                             device
# 164                                           platform
# 165                                                cdn
# 166                                               tool
#
#                                          twist-used-in  \
# 0                                mobile,webapp,desktop
# 1                                 software-development
# 2    under-revision,desktop,mobile,webapp,software-...
# 3    under-revision,network,blockchain,webapp,security
# 4    software-development-process,mobile,webapp,sof...
# 5                       mobile,webapp,desktop,embedded
# 6    mobile,webapp,desktop,software-development,fro...
# 7                          graphics,entertainment,game
# 8                software-development-process,hardware
# 9                                 software-development
# 10                      desktop,mobile,webapp,frontend
# 11                      desktop,mobile,webapp,embedded
# 12   desktop,mobile,webapp,software-development-pro...
# 13   entertainment,education,visualization,web,chat...
# 14           scientific,ai,bioinformatics,data-science
# 15   software-development-process,web,frontend,iot,...
# 16   mobile,webapp,desktop,embedded,cloud-computing...
# 17                               webapp,desktop,mobile
# 18   mobile,desktop,webapp,cloud-computing,software...
# 19   graphics,scientific,ai,data-science,computer-v...
# 20              education,software-development-process
# 21   under-revision,software-development-process,so...
# 22                                            database
# 23   ai,scientific,computer-vision,machine-learning...
# 24   software-development-process,visualization,und...
# 25         software-development-process,under-revision
# 26                                       entertainment
# 27                                              mobile
# 28   social-network,iot,web,network,virtualization,...
# 29                                                 web
# 30   hardware,software-development-process,educatio...
# 31             game,mobile,webapp,software-development
# 32                                       mobile,webapp
# 33                                     cloud-computing
# 34   webapp,cloud-computing,computer-vision,softwar...
# 35                                             network
# 36                                software-development
# 37                              graphics,mobile,webapp
# 38                                            database
# 39                                          blockchain
# 40                                                game
# 41                 desktop,mobile,software-development
# 42
# 43                                                game
# 44                                software-development
# 45                                       game,hardware
# 46   scientific,desktop,embedded,mobile,software-de...
# 47                                                game
# 48                                         web,browser
# 49                                                game
# 50            mobile,webapp,cloud-computing,blockchain
# 51                                                game
# 52   mobile,webapp,software-development-process,har...
# 53                                                game
# 54                       chrome,firefox,netbox,browser
# 55                                                 web
# 56                                software-development
# 57                          mobile,webapp,web,security
# 58                                       game,hardware
# 59                                    competition,game
# 60                        software-development-process
# 61                                       entertainment
# 62                      telecommunication,iot,web,game
# 63                                      under-revision
# 64                                                game
# 65                software-development,computer-vision
# 66                                              webapp
# 67                                   mobile,webapp,web
# 68
# 69                        software-development-process
# 70                                                chat
# 71                  software-development,mobile,webapp
# 72                                                 iot
# 73                                              webapp
# 74                                            database
# 75                                            database
# 76                                                game
# 77                                          blockchain
# 78   software-development,computer-vision,ai,deep-l...
# 79   hardware,software-development-process,under-re...
# 80                                      social-network
# 81                           software-development,game
# 82                        software-development-process
# 83          software-development,desktop,mobile,webapp
# 84        visualization,data-science,scientific,webapp
# 85                                       mobile,webapp
# 86   software-development-process,software-development
# 87                                            database
# 88                        software-development-process
# 89                cloud-computing,software-development
# 90
# 91                                                 web
# 92   software-development,software-development-process
# 93
# 94                                       entertainment
# 95                system-administration,virtualization
# 96                                                game
# 97                                          scientific
# 98                                           education
# 99                                       mobile,webapp
# 100                                     scientific,iot
# 101                       software-development-process
# 102                                             webapp
# 103                          bioinformatics,scientific
# 104                                             webapp
# 105                                    cloud-computing
# 106                                 ai,computer-vision
# 107                                          education
# 108                       software-development-process
# 109                                         scientific
# 110                                     under-revision
# 111                             mobile,webapp,security
# 112                                            network
# 113                                          education
# 114                                             webapp
# 115                                               game
# 116                                             webapp
# 117                                                art
# 118                       software-development-process
# 119                                          education
# 120                                ai,machine-learning
# 121                                          education
# 122                               software-development
# 123                                             chrome
# 124                                           graphics
# 125                                         blockchain
# 126                                   ai,deep-learning
# 127                                    computer-vision
# 128                                           database
# 129                               software-development
# 130                                    computer-vision
# 131                                      mobile,webapp
# 132                               software-development
# 133                       software-development-process
# 134                                           database
# 135                                      visualization
# 136                                         scientific
# 137
# 138                              desktop,mobile,webapp
# 139                              desktop,mobile,webapp
# 140                               software-development
# 141                                                art
# 142                            data-science,scientific
# 143                                           database
# 144                                  telecommunication
# 145                       software-development-process
# 146                                           database
# 147                                           graphics
# 148                       software-development-process
# 149                                            firefox
# 150                                             netbox
# 151
# 152                            desktop,embedded,mobile
# 153                                                iot
# 154                       software-development-process
# 155
# 156                                                iot
# 157                                         scientific
# 158                          bioinformatics,scientific
# 159
# 160                                           database
# 161                       software-development-process
# 162                                                art
# 163
# 164                                               game
# 165                                     under-revision
# 166                              system-administration
#
#                                         twist-used-for  \
# 0    dynamic,search,frontend,backend,authentication...
# 1
# 2    event-driven,frontend,backend,ui-ux,testing,si...
# 3    event-driven,manage,visualization,automation,u...
# 4    automation,cicd,dynamic,manage,monitoring,pars...
# 5    dynamic,search,frontend,authentication,securit...
# 6    dynamic,frontend,ui-ux,backend,automation,html...
# 7    3d-printing,game,virtual-reality,2d,android,ht...
# 8    automation,cicd,manage,monitoring,code-quality...
# 9                             parsing,manage,container
# 10                   frontend,backend,ui-ux,automation
# 11                              frontend,ui-ux,backend
# 12               frontend,ui-ux,collaboration,graphics
# 13                                   manage,automation
# 14         visualization,control,image-processing,code
# 15   automation,cicd,manage,monitoring,privacy,test...
# 16   frontend,ui-ux,communication,event-driven,grap...
# 17                                    backend,frontend
# 18                        frontend,container,streaming
# 19      3d-printing,game,virtual-reality,visualization
# 20                code-review,education,grading,portal
# 21          event-driven,testing,backend,communication
# 22               nosql,modeling,relational,graph-based
# 23
# 24                   automation,cicd,manage,monitoring
# 25                      manage,monitoring,code-quality
# 26
# 27
# 28         communication,security,authentication,addon
# 29            automation,search,communication,security
# 30
# 31   2d,android,html5,ios,linux,macos,windows,3d,gr...
# 32
# 33                              as-a-service,container
# 34                                             backend
# 35                                              manage
# 36
# 37     3d-printing,game,virtual-reality,graphics,ui-ux
# 38                        nosql,relational,graph-based
# 39
# 40         2d,android,html5,ios,linux,macos,windows,3d
# 41                                      frontend,ui-ux
# 42
# 43         2d,android,html5,ios,linux,macos,windows,3d
# 44
# 45         2d,android,html5,ios,linux,macos,windows,3d
# 46      image-processing,ui-ux,automation,microservice
# 47         2d,android,html5,ios,linux,macos,windows,3d
# 48                                               addon
# 49
# 50                authentication,security,as-a-service
# 51         2d,android,html5,ios,linux,macos,windows,3d
# 52                               search,2d,3d,graphics
# 53         android,2d,html5,ios,linux,macos,windows,3d
# 54                                               addon
# 55                              communication,security
# 56
# 57               authentication,security,communication
# 58         2d,3d,android,html5,ios,linux,macos,windows
# 59                                               html5
# 60                                  testing,automation
# 61                                     android,windows
# 62                                             control
# 63
# 64         2d,android,html5,ios,linux,macos,windows,3d
# 65
# 66                                            frontend
# 67                                              search
# 68
# 69                   automation,cicd,manage,monitoring
# 70
# 71                                               ui-ux
# 72                          automation,privacy,control
# 73                                            frontend
# 74                                          relational
# 75                                               nosql
# 76
# 77
# 78
# 79                                               2d,3d
# 80
# 81                                            2d,html5
# 82                   automation,cicd,manage,monitoring
# 83
# 84                                manage,visualization
# 85                                     site-generation
# 86                                          automation
# 87
# 88                                          automation
# 89                                           container
# 90
# 91                                              search
# 92                                          automation
# 93
# 94
# 95                           automation,virtualization
# 96
# 97                                              manage
# 98
# 99                                        microservice
# 100                                            control
# 101
# 102                            site-generation,backend
# 103
# 104                                           frontend
# 105                                       as-a-service
# 106
# 107                                            grading
# 108                                collaboration,ui-ux
# 109
# 110                                       event-driven
# 111                            authentication,security
# 112
# 113
# 114                                     frontend,ui-ux
# 115
# 116                                            backend
# 117                                         publishing
# 118                                            testing
# 119                                            grading
# 120
# 121                                             portal
# 122                                            parsing
# 123
# 124                   3d-printing,game,virtual-reality
# 125
# 126
# 127
# 128                                        graph-based
# 129
# 130
# 131                                            dynamic
# 132
# 133                              code-review,education
# 134                                        graph-based
# 135                                             manage
# 136                                               code
# 137
# 138                                              ui-ux
# 139                                              ui-ux
# 140
# 141                                         publishing
# 142                                      visualization
# 143                                           modeling
# 144
# 145
# 146                                         relational
# 147                   3d-printing,game,virtual-reality
# 148                              code-review,education
# 149
# 150
# 151
# 152                                              ui-ux
# 153                                 automation,privacy
# 154                                       code-quality
# 155
# 156                                            control
# 157                                   image-processing
# 158
# 159
# 160                                           modeling
# 161
# 162                                         publishing
# 163
# 164                                          streaming
# 165
# 166                          automation,virtualization
#
#                                       twist-works-with
# 0    javascript,css,html,python,go,ruby,php,macos,java
# 1
# 2    php,javascript,dotnet,css,html,python,go,ruby,...
# 3                              php,cli,java,javascript
# 4    javascript,x-window,elixir,minecraft,java,ansi...
# 5                         javascript,dotnet,java,macos
# 6    javascript,css,html,typescript,c,cpp,java,matl...
# 7                      minecraft,javascript,typescript
# 8            php,elixir,git,github,java,ansible,nodejs
# 9    typescript,javascript,clojure,php,c,cpp,lua,no...
# 10                          javascript,dotnet,css,html
# 11                              javascript,dotnet,java
# 12                    dotnet,javascript,java,macos,css
# 13                                            x-window
# 14                                                java
# 15                       javascript,java,github,nodejs
# 16   javascript,java,python,c,cpp,matlab,octave,php...
# 17                       python,javascript,go,php,ruby
# 18                                              dotnet
# 19
# 20                                              elixir
# 21                                                 php
# 22                                  mongodb,sql,cypher
# 23                                          python,cpp
# 24                                            x-window
# 25
# 26
# 27
# 28
# 29
# 30
# 31                                         linux,macos
# 32                                php,aspnet,wordpress
# 33                                              python
# 34          python,c,cpp,java,javascript,matlab,octave
# 35
# 36
# 37                                    macos,javascript
# 38                                          sql,cypher
# 39                                            ethereum
# 40                               javascript,typescript
# 41                                              dotnet
# 42
# 43                                         linux,macos
# 44                php,c,cpp,macos,nodejs,dotnet,python
# 45                               javascript,typescript
# 46          java,c,cpp,javascript,matlab,octave,python
# 47                               javascript,typescript
# 48                                          javascript
# 49
# 50                                            ethereum
# 51
# 52                                   github,javascript
# 53
# 54
# 55                                                 php
# 56                       typescript,javascript,clojure
# 57
# 58
# 59                                          javascript
# 60                                         php,ansible
# 61
# 62                                      siri,minecraft
# 63                                     linux,macos,cli
# 64
# 65          c,cpp,java,javascript,matlab,octave,python
# 66                                                html
# 67
# 68
# 69
# 70
# 71                                               macos
# 72                                                siri
# 73
# 74                                                 sql
# 75
# 76
# 77
# 78          c,cpp,java,javascript,matlab,octave,python
# 79
# 80
# 81                               typescript,javascript
# 82
# 83                           javascript,typescript,lua
# 84                                            x-window
# 85                                                ruby
# 86
# 87
# 88                                       github,nodejs
# 89
# 90
# 91
# 92                                       nodejs,github
# 93
# 94
# 95
# 96                                           minecraft
# 97
# 98
# 99                                     javascript,java
# 100                                               siri
# 101                                                git
# 102                                               ruby
# 103
# 104                                css,html,javascript
# 105
# 106         c,cpp,java,javascript,matlab,octave,python
# 107
# 108
# 109
# 110                                                php
# 111
# 112
# 113
# 114                                css,html,javascript
# 115
# 116                                                 go
# 117
# 118                                            ansible
# 119
# 120                                             python
# 121
# 122
# 123
# 124
# 125                                           ethereum
# 126                                         cpp,python
# 127         c,cpp,java,javascript,matlab,octave,python
# 128                                             cypher
# 129                                                lua
# 130         c,cpp,java,javascript,matlab,octave,python
# 131                                         javascript
# 132                                            clojure
# 133                                             elixir
# 134                                             cypher
# 135                                           x-window
# 136
# 137
# 138
# 139                                         javascript
# 140                                         javascript
# 141
# 142
# 143                                            mongodb
# 144
# 145
# 146                                                sql
# 147
# 148                                             elixir
# 149
# 150
# 151                                          wordpress
# 152                                               java
# 153
# 154
# 155                                             aspnet
# 156                                               siri
# 157                                               java
# 158
# 159                                            haskell
# 160                                            mongodb
# 161                                                git
# 162
# 163
# 164
# 165
# 166

# %% [markdown]
# # Display top 20 repos of a topic

# %%
def show_repos(repos):
    print()
    for i in range(len(repos)):
        item = repos[i]
        l = item['link']
        s = item['stargazers']
        print("{:<6} {:<10} {:<100}".format(i+1,s,l))
        print()
    return

# %% [markdown]
# # Display info on a topic

# %%
def show_tag_info(t):    
    print(('@@'*50+'\n')*3)
    print('\n\t'+'##'*20+' '+t+' Info\n')
    with open('./topics/'+t+'/index.md','r') as f:
        content = f.read()
        print(content)

# %% [markdown]
# # Review the topics
# # NOTICE : Remove the 'revision_done.json' file or modify the list of 'done' topics in the file so that the information is displayed. This file persists your progress.
# # NOTICE : As soon as you move on to the next topic by pressing Enter, the previous topic will be excluded from any future executions unless you remove it from the 'revision_done.json' file.
# # NOTICE : Type in 'e' at any time you are asked for an input to stop revising the topics. This will not persist your revision on the current topic.
# # NOTICE : Set verbose to False for a less verbose option. (not recommended)

# %%
verbose = True

try:
    with open('revision_done.json','r') as f:
        done = json.load(f)['done']
except:
    done = [].copy()

for r in rhs:
    resp = ''
    lhss = sorted(list(set(rels.loc[rels.rhs==r,'lhs']).difference(set(done))))
    
    if verbose:
        resp = input('\nNew RHS started with '+str(len(lhss))+' LHS === '+r+'\n')
        if resp == 'e':
            break
        display(df.loc[df.key == r,['key','count','is-a','used-in','used-for','works-with']])
    while True:
        try:
            l = lhss[0]
        except:
            break
        check = rels.loc[rels.lhs==l].copy()
        show_tag_info(l)
        display(check)
        resp = input('Enter if you are done with this tag or type in "m" for more information (top 20 repos with the tag):\n')
        if resp == 'm':
            show_repos(topics[l]['top_20'])
            resp = input('Enter if you are done with this tag: ')
        if resp == 'e':
            break
        done.append(lhss.pop(0))
        with open('revision_done.json','w') as f:
            json.dump({'done':done},f)
    if resp == 'e':
        break
# Out:
# New RHS started with 0 LHS === webapp
#  e
